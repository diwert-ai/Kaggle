# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import files

files.upload() #this will prompt you to upload the kaggle.json
# Out:
#      <input type="file" id="files-d94d7205-1748-4c4c-a354-0d21a96693ce" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d94d7205-1748-4c4c-a354-0d21a96693ce">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"andreyzotov","key":"79d4b3e1096f2a2d9bef47b96813ceaa"}'}

# %%
# !pip install -q kaggle --upgrade
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !ls ~/.kaggle
# we need to set permissions 
# !chmod 600 /root/.kaggle/kaggle.json
# Out:
# kaggle.json

# %%
import os
os.chdir('/content/drive/My Drive/kaggle/gi_t_is/input/')

# %%
# !ls -a
# Out:
# 2d-224x224.zip	       uw-madison-gi-tract-image-segmentation.zip
# sample_submission.csv  uwmgi-mask-dataset.zip
# train.csv

# %%
# !kaggle datasets download awsaf49/uwmgi-mask-dataset
# Out:
# ...
#  96% 74.0M/77.3M [00:00<00:00, 120MB/s]
# 100% 77.3M/77.3M [00:00<00:00, 94.3MB/s]

# %%
# !kaggle datasets download andreyzotov/2d-224x224
# Out:
# ...
# 100% 1.60G/1.60G [00:27<00:00, 45.7MB/s]
# 100% 1.60G/1.60G [00:27<00:00, 62.0MB/s]

# %%
# !kaggle datasets download -d andreyzotov/resized-320x384
# Out:
# ...
#  99% 2.57G/2.58G [00:31<00:00, 149MB/s]
# 100% 2.58G/2.58G [00:31<00:00, 88.5MB/s]

# %%
# !kaggle datasets download -h
# Out:
# usage: kaggle datasets download [-h] [-f FILE_NAME] [-p PATH] [-w] [--unzip]
#                                 [-o] [-q]
#                                 [dataset]
#
# optional arguments:
#   -h, --help            show this help message and exit
#   dataset               Dataset URL suffix in format <owner>/<dataset-name> (use "kaggle datasets list" to show options)
#   -f FILE_NAME, --file FILE_NAME
#                         File name, all files downloaded if not provided
#                         (use "kaggle datasets files -d <dataset>" to show options)
#   -p PATH, --path PATH  Folder where file(s) will be downloaded, defaults to current working directory
#   -w, --wp              Download files to current working path
#   --unzip               Unzip the downloaded file. Will delete the zip file when completed.
#   -o, --force           Skip check whether local version of file is up to date, force file download
# ...

# %%
# !kaggle competitions download -p '/content/drive/My Drive/kaggle/gi_t_is/input/' -c uw-madison-gi-tract-image-segmentation
# Out:
# ...
#  99% 2.29G/2.30G [00:24<00:00, 140MB/s]
# 100% 2.30G/2.30G [00:25<00:00, 98.6MB/s]

# %%
# !kaggle kernels pull -h
# Out:
# usage: kaggle kernels pull [-h] [-p PATH] [-w] [-m] [kernel]
#
# optional arguments:
#   -h, --help            show this help message and exit
#   kernel                Kernel URL suffix in format <owner>/<kernel-name> (use "kaggle kernels list" to show options)
#   -p PATH, --path PATH  Folder where file(s) will be downloaded, defaults to current working directory
#   -w, --wp              Download files to current working path
#   -m, --metadata        Generate metadata when pulling kernel

# %%
# !kaggle kernels pull andreyzotov/bengali-analisis -p '/content/drive/My Drive/kaggle/bengali/nbs/'
# Out:
# ...
# Source code downloaded to /content/drive/My Drive/kaggle/bengali/nbs/bengali-analisis.ipynb

# %%
# !kaggle kernels list -m
# Out:
# ...
# ref                                                           title                                               author        lastRunTime          totalVotes
# ------------------------------------------------------------  --------------------------------------------------  ------------  -------------------  ----------
# andreyzotov/qubvel-classification-models-test                 qubvel_classification_models test                   Andrey Zotov  2020-02-18 17:05:27           1
# andreyzotov/script-mixup-hr-20eps                             script mixup hr 20eps                               Andrey Zotov  2020-01-19 16:57:23           0
# andreyzotov/compute-recall-train-valid-set-model-fold0        compute recall [train/valid set] [model fold0]      Andrey Zotov  2020-01-20 12:11:04           0
# andreyzotov/cosine-anneling-test                              cosine anneling test                                Andrey Zotov  2020-01-01 15:16:00           0
# ...

# %%
# !ls

# %%
# !unzip
# Out:
# UnZip 6.00 of 20 April 2009, by Debian. Original by Info-ZIP.
#
# Usage: unzip [-Z] [-opts[modifiers]] file[.zip] [list] [-x xlist] [-d exdir]
#   Default action is to extract files in list, except those in xlist, to exdir;
#   file[.zip] may be a wildcard.  -Z => ZipInfo mode ("unzip -Z" for usage).
#
#   -p  extract files to pipe, no messages     -l  list files (short format)
#   -f  freshen existing files, create none    -t  test compressed archive data
#   -u  update files, create if necessary      -z  display archive comment only
#   -v  list verbosely/show version info       -T  timestamp archive to latest
#   -x  exclude files that follow (in xlist)   -d  extract files into exdir
# modifiers:
#   -n  never overwrite existing files         -q  quiet mode (-qq => quieter)
#   -o  overwrite files WITHOUT prompting      -a  auto-convert any text files
#   -j  junk paths (do not make directories)   -aa treat ALL files as text
# ...

# %%
# !kaggle datasets download -d xhlulu/siim-covid19-resized-to-256px-jpg
# Out:
# ...
#  83% 41.0M/49.5M [00:01<00:00, 39.3MB/s]
# 100% 49.5M/49.5M [00:01<00:00, 44.2MB/s]

# %%
# !kaggle datasets download -d shonenkov/birdcall-check
# Out:
# ...
#  85% 13.0M/15.3M [00:01<00:00, 9.19MB/s]
# 100% 15.3M/15.3M [00:01<00:00, 9.32MB/s]

# %%
# !mkdir /content/local_data

# %%
# !ls
# Out:
# siimcovid19-256-jpg-image-dataset.zip

# %%
# !unzip -q siimcovid19-256-jpg-image-dataset.zip

# %%
# !kaggle competitions download -c birdsong-recognition

# %%
# !kaggle datasets download -d rohanrao/xeno-canto-bird-recordings-extended-a-m
# Out:
# ...
# 100% 16.6G/16.6G [04:38<00:00, 47.6MB/s]
# 100% 16.6G/16.6G [04:39<00:00, 63.7MB/s]

# %%
# !kaggle datasets list -s birdsong-recognition
# Out:
# ...
# ref                                                               title                                                size  lastUpdated          downloadCount
# ----------------------------------------------------------------  --------------------------------------------------  -----  -------------------  -------------
# anshuls235/birdsongrecognitiondetails                             birdsong-recognition-details                         38KB  2020-06-24 18:20:50              7
# rohanrao/xeno-canto-bird-recordings-extended-a-m                  Xeno-Canto Bird Recordings Extended (A-M)            17GB  2020-08-18 14:34:56            374
# rohanrao/xeno-canto-bird-recordings-extended-n-z                  Xeno-Canto Bird Recordings Extended (N-Z)            10GB  2020-08-18 14:49:04            335
# ttahara/birdsong-resampled-train-audio-00                         birdsong resampled train audio 00 (a ~ b)            12GB  2020-07-04 13:16:57            795
# ...

# %%
# !kaggle datasets download -d shonenkov/melanoma-merged-external-data-512x512-jpeg
# Out:
# ...
# 100% 4.85G/4.86G [01:10<00:00, 61.1MB/s]
# 100% 4.86G/4.86G [01:10<00:00, 73.6MB/s]

# %%
# !ls
# Out:
# folds_08062020.csv  melanoma-merged-external-data-512x512-jpeg.zip  test.csv
# folds.csv	    sample_submission.csv
# marking.csv	    subs

# %%
# !kaggle datasets download -d andreyzotov/bengali-137x235-woinorm
# Out:
# ...
# 100% 1.80G/1.81G [00:14<00:00, 134MB/s]
# 100% 1.81G/1.81G [00:14<00:00, 133MB/s]

# %%
# Out:
#  224x224-bengali.zip	    'kaggle (1).json'	     train.csv
#  class_map.csv		     kaggle.json	     train_with_fold.csv
#  grapheme-imgs-128x128.zip   sample_submission.csv

# %%
# !unzip grapheme-imgs-128x128.zip -d 128

# %%
# !kaggle datasets
# Out:
# usage: kaggle datasets [-h]
#                        {list,files,download,create,version,init,metadata,status}
#                        ...
# kaggle datasets: error: too few arguments

# %%
# !kaggle competitions download bengaliai-cv19 -f train.csv
# Out:
# train.csv.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# Out:
#   19876  178877 1150558

# %%
# !kaggle kernels list -m
# Out:
# ...
# ref                                                    title                                        author        lastRunTime          totalVotes
# -----------------------------------------------------  -------------------------------------------  ------------  -------------------  ----------
# andreyzotov/128x128-densenet-121                       128x128 Densenet 121                         Andrey Zotov  2019-12-31 19:36:16           0
# andreyzotov/submit-test-new-formula                    submit test (new formula)                    Andrey Zotov  2019-12-31 10:45:22           0
# andreyzotov/submit-flowfromdf-test                     submit flowfromdf test                       Andrey Zotov  2019-12-28 23:09:51           0
# andreyzotov/k-mnist-analisis                           K-MNIST Analisis                             Andrey Zotov  2019-12-16 07:59:12           0
# ...
