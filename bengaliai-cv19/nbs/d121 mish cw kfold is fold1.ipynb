# %%
# !ls
# Out:
# drive  sample_data  train

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !mkdir train
# !mkdir train/128

# %%
# !cp '/content/drive/My Drive/kaggle/bengali/input/grapheme-imgs-128x128.zip' train
# !cp '/content/drive/My Drive/kaggle/bengali/input/train_with_fold.csv' train

# %%
# !unzip train/grapheme-imgs-128x128.zip  -d train/128/

# %%
# !ls train
# Out:
# 128  grapheme-imgs-128x128.zip	train_with_fold.csv

# %%
# %tensorflow_version 2.x

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import cv2
import math

import tensorflow as tf
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import LeakyReLU
from keras.layers.normalization import BatchNormalization
from tensorflow.keras.callbacks import ReduceLROnPlateau,LambdaCallback
from tensorflow.keras.applications.densenet import DenseNet121
from tensorflow.keras.models import load_model
from tensorflow.keras import layers
from tensorflow.keras.callbacks import Callback
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Activation
from tensorflow.keras.utils import get_custom_objects
from sklearn.utils import class_weight
from tensorflow.python.client import device_lib


# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
#for dirname, _, filenames in os.walk('/kaggle/input'):
#    for filename in filenames:
#        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.

# %%
train_dir='./train/128'

# %%
dataset_np = pd.read_csv('./train/train_with_fold.csv').to_numpy()
dataset_np[:,0]+='.png'
dataset_m = dataset_np.shape[0]
fold = 1

valid_m = np.where(dataset_np[:,6]==fold)[0].shape[0]
train_m = dataset_m-valid_m

fold_train_inds = np.where(dataset_np[:,6] != fold)
fold_valid_inds = np.where(dataset_np[:,6] == fold)

train_np = dataset_np[fold_train_inds]
valid_np = dataset_np[fold_valid_inds]

train_df = pd.DataFrame(train_np)
valid_df = pd.DataFrame(valid_np)

train_df.rename(columns={0:'filename',1:'root_class',2:'vowel_class',3:'cons_class', 4:'grapheme'}, inplace=True)
valid_df.rename(columns={0:'filename',1:'root_class',2:'vowel_class',3:'cons_class', 4:'grapheme'}, inplace=True)

train_df.drop(columns=[5,6], inplace=True)
valid_df.drop(columns=[5,6], inplace=True)

# %%
cons_unique=np.unique(train_np[:,3])
cons_y_train = train_np[:,3]
vowel_unique=np.unique(train_np[:,2])
vowel_y_train = train_np[:,2]
root_unique =np.unique(train_np[:,1])
root_y_train = train_np[:,1]

cons_class_weights = class_weight.compute_class_weight('balanced',
                                                 cons_unique,
                                                 cons_y_train)

vowel_class_weights = class_weight.compute_class_weight('balanced',
                                                 vowel_unique,
                                                 vowel_y_train)

root_class_weights = class_weight.compute_class_weight('balanced',
                                                 root_unique,
                                                 root_y_train)
cons_cw_dict=dict(enumerate(cons_class_weights))
vowel_cw_dict=dict(enumerate(vowel_class_weights))
root_cw_dict=dict(enumerate(root_class_weights))

model_cw={}
model_cw['root']=root_cw_dict
model_cw['vowel']=vowel_cw_dict
model_cw['consonant']=cons_cw_dict

# %%
class Mish(Activation):
    '''
    Mish Activation Function.
    .. math::
        mish(x) = x * tanh(softplus(x)) = x * tanh(ln(1 + e^{x}))
    Shape:
        - Input: Arbitrary. Use the keyword argument `input_shape`
        (tuple of integers, does not include the samples axis)
        when using this layer as the first layer in a model.
        - Output: Same shape as the input.
    Examples:
        >>> X = Activation('Mish', name="conv1_act")(X_input)
    '''

    def __init__(self, activation, **kwargs):
        super(Mish, self).__init__(activation, **kwargs)
        self.__name__ = 'Mish'


def mish(inputs):
    return inputs * tf.math.tanh(tf.math.softplus(inputs))

get_custom_objects().update({'Mish': Mish(mish)})

# %%
densenet = DenseNet121(include_top=False, weights=None, input_shape=(128, 128, 3))

# %%
def build_head(x_in, n, name=None):
  x = layers.GlobalAveragePooling2D()(x_in)
  x = Activation('Mish', name='mish_act1_'+name) (x)
  x = layers.BatchNormalization()(x)
  x = layers.Dropout(0.5)(x)
  x = layers.Dense(512)(x)
  x = Activation('Mish', name='mish_act2_'+name) (x)
  x = layers.BatchNormalization()(x)
  x = layers.Dropout(0.5)(x)
  x = layers.Dense(n, name=name, activation='softmax')(x)
  return x

# %%
def build_model(densenet):
    x_in = layers.Input(shape=(128, 128, 3))
    x = densenet(x_in)
    out_root = build_head(x, 168,'root')
    out_vowel = build_head(x, 11,'vowel')
    out_consonant = build_head(x,7,'consonant')
    
    model = tf.keras.Model(inputs=x_in, outputs=[out_root, out_vowel, out_consonant])
    
    return model

# %%
model = build_model(densenet)

# %%
for (n, layer) in enumerate(model.layers[1].layers):
  if 'activation' in layer.get_config() and layer.get_config()['activation'] == 'relu':
        #print('replacing #{}: {}, {}'.format(n, layer, layer.activation))
        layer.activation = Mish(mish)
        #print('-> {}'.format(layer.activation))

# %%
import tempfile

def apply_modifications(model, custom_objects=None):
    """Applies modifications to the model layers to create a new Graph. For example, simply changing
    `model.layers[idx].activation = new activation` does not change the graph. The entire graph needs to be updated
    with modified inbound and outbound tensors because of change in layer building function.
    Args:
        model: The `keras.models.Model` instance.
    Returns:
        The modified model with changes applied. Does not mutate the original `model`.
    """
    # The strategy is to save the modified model and load it back. This is done because setting the activation
    # in a Keras layer doesnt actually change the graph. We have to iterate the entire graph and change the
    # layer inbound and outbound nodes with modified tensors. This is doubly complicated in Keras 2.x since
    # multiple inbound and outbound nodes are allowed with the Graph API.
    model_path = os.path.join(tempfile.gettempdir(), next(tempfile._get_candidate_names()) + '.h5')
    try:
        model.save(model_path)
        return load_model(model_path, custom_objects=custom_objects)
    finally:
        os.remove(model_path)

# %%
model = apply_modifications(model, custom_objects={'mish':Mish(mish)})
# Out:
# WARNING:tensorflow:No training configuration found in save file: the model was *not* compiled. Compile it manually.

# %%
loss_dict={'root': 'categorical_crossentropy',
           'vowel':    'categorical_crossentropy',
           'consonant':'categorical_crossentropy'}
           
metrics_dict={ 'root':     [tf.keras.metrics.Recall(name='recall')],
               'vowel':    [tf.keras.metrics.Recall(name='recall')],
              'consonant': [tf.keras.metrics.Recall(name='recall')]}

#metrics_dict={ 'root':     ['accuracy'],
#               'vowel':    ['accuracy'],
#               'consonant':['accuracy']}


model.compile(optimizer='adam', loss=loss_dict, loss_weights=[2.0,1.0,1.0], 
                  metrics=metrics_dict)

# %%
#tf.keras.utils.plot_model(model, to_file='model.png', show_shapes=True)

# %%
train_datagen = ImageDataGenerator(rotation_range = 10,
                                   shear_range = 0.1)

valid_datagen = ImageDataGenerator()

# %%
columns=["root_class","vowel_class", "cons_class"]
batch_size = 32
train_generator = train_datagen.flow_from_dataframe(
        dataframe=train_df,
        directory=train_dir,
        x_col="filename",
        y_col=columns,
        target_size=(128, 128),
        batch_size=batch_size,
        class_mode="multi_output",
        colormode="greyscale")

valid_generator = valid_datagen.flow_from_dataframe(
        dataframe=valid_df,
        directory=train_dir,
        x_col="filename",
        y_col=columns,
        target_size=(128, 128),
        batch_size=batch_size,
        class_mode="multi_output",
        colormode="greyscale")
# Out:
# Found 160672 validated image filenames.
# Found 40168 validated image filenames.

# %%
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 12280484651661344698, name: "/device:XLA_CPU:0"
#  device_type: "XLA_CPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 6315995650637907960
#  physical_device_desc: "device: XLA_CPU device", name: "/device:XLA_GPU:0"
#  device_type: "XLA_GPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 3941675327942847520
#  physical_device_desc: "device: XLA_GPU device", name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 15956161332
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 10695490761184805515
#  physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0"]

# %%
def split_into_3_outputs(y_batch):
    
    y1=tf.keras.utils.to_categorical(y_batch[0],168)
    y2=tf.keras.utils.to_categorical(y_batch[1],11)
    y3=tf.keras.utils.to_categorical(y_batch[2],7)
    
    return y1,y2,y3

# %%
def aux_data_gen(generator):
    stats = (0.0692, 0.2051)
    while True:
        batch = next(generator)
        batch_x = (batch[0].astype(np.float32)/255.0 - stats[0])/stats[1]
        yield batch_x, split_into_3_outputs(batch[1])

# %%
class CosineAnnealingScheduler(Callback):
    """Cosine annealing scheduler.
    """

    def __init__(self, T_max, eta_max, eta_min=0, verbose=0):
        super(CosineAnnealingScheduler, self).__init__()
        self.T_max = T_max
        self.eta_max = eta_max
        self.eta_min = eta_min
        self.verbose = verbose

    def on_epoch_begin(self, epoch, logs=None):
        if not hasattr(self.model.optimizer, 'lr'):
            raise ValueError('Optimizer must have a "lr" attribute.')
        lr = self.eta_min + (self.eta_max - self.eta_min) * (1 + math.cos(math.pi * epoch / self.T_max)) / 2
        K.set_value(self.model.optimizer.lr, lr)
        if self.verbose > 0:
            print('\nEpoch %05d: CosineAnnealingScheduler setting learning '
                  'rate to %s.' % (epoch + 1, lr))

    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        logs['lr'] = K.get_value(self.model.optimizer.lr)

# %%
epochs = 40

ca_shed = CosineAnnealingScheduler(T_max=epochs, eta_max=1e-3, eta_min=1e-6,verbose=1)

history=model.fit_generator(aux_data_gen(train_generator),
                    validation_data=aux_data_gen(valid_generator),
                    epochs=epochs,
                    steps_per_epoch=train_m//batch_size+1,
                    validation_steps = valid_m//batch_size+1,
                    callbacks=[ca_shed],
                    class_weight=model_cw)

history.history['weighted_recall']= 0.5*np.array(history.history['root_recall'])+0.25*np.array(history.history['consonant_recall'])+0.25*np.array(history.history['vowel_recall'])
history.history['val_weighted_recall']= 0.5*np.array(history.history['val_root_recall'])+0.25*np.array(history.history['val_consonant_recall'])+0.25*np.array(history.history['val_vowel_recall'])

model.save_weights('/content/drive/My Drive/kaggle/bengali/output/w_mishdense_eps40_sr02_bs32_adam_cw_fold'+str(fold)+'.h5')
model.save('/content/drive/My Drive/kaggle/bengali/output/m_mishdense_eps40_sr02_bs32_adam_cw_fold'+str(fold)+'.h5')
pd.DataFrame(history.history).to_csv('/content/drive/My Drive/kaggle/bengali/output/h_mishdense_eps40_sr02_bs32_adam_cw_fold'+str(fold)+'.csv', index=False)
# Out:
# WARNING:tensorflow:From <ipython-input-36-3884a5a9d73f>:11: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Train for 5022 steps, validate for 1256 steps
#
# Epoch 00001: CosineAnnealingScheduler setting learning rate to 0.0001.
# Epoch 1/40
# 5022/5022 [==============================] - 913s 182ms/step - loss: 9.6224 - root_loss: 3.8195 - vowel_loss: 0.9834 - consonant_loss: 1.0001 - root_recall: 0.0441 - vowel_recall: 0.6167 - consonant_recall: 0.4832 - val_loss: 3.8357 - val_root_loss: 1.5139 - val_vowel_loss: 0.3140 - val_consonant_loss: 0.4939 - val_root_recall: 0.2720 - val_vowel_recall: 0.8411 - val_consonant_recall: 0.6541
#
# Epoch 00002: CosineAnnealingScheduler setting learning rate to 9.984740801978984e-05.
# Epoch 2/40
# 5022/5022 [==============================] - 891s 177ms/step - loss: 3.3452 - root_loss: 1.3005 - vowel_loss: 0.3765 - consonant_loss: 0.3676 - root_recall: 0.3998 - vowel_recall: 0.8426 - consonant_recall: 0.7972 - val_loss: 1.5474 - val_root_loss: 0.5875 - val_vowel_loss: 0.1914 - val_consonant_loss: 0.1810 - val_root_recall: 0.7021 - val_vowel_recall: 0.9201 - val_consonant_recall: 0.9212
#
# Epoch 00003: CosineAnnealingScheduler setting learning rate to 9.939057285945933e-05.
# Epoch 3/40
# 5022/5022 [==============================] - 903s 180ms/step - loss: 2.0065 - root_loss: 0.7524 - vowel_loss: 0.2472 - consonant_loss: 0.2545 - root_recall: 0.6502 - vowel_recall: 0.8972 - consonant_recall: 0.8607 - val_loss: 1.7102 - val_root_loss: 0.6062 - val_vowel_loss: 0.2240 - val_consonant_loss: 0.2737 - val_root_recall: 0.6998 - val_vowel_recall: 0.9179 - val_consonant_recall: 0.8806
#
# Epoch 00004: CosineAnnealingScheduler setting learning rate to 9.8632311059685e-05.
# Epoch 4/40
# 5022/5022 [==============================] - 882s 176ms/step - loss: 1.4916 - root_loss: 0.5473 - vowel_loss: 0.1955 - consonant_loss: 0.2014 - root_recall: 0.7493 - vowel_recall: 0.9214 - consonant_recall: 0.8896 - val_loss: 0.9974 - val_root_loss: 0.3686 - val_vowel_loss: 0.1281 - val_consonant_loss: 0.1321 - val_root_recall: 0.8380 - val_vowel_recall: 0.9499 - val_consonant_recall: 0.9429
#
# Epoch 00005: CosineAnnealingScheduler setting learning rate to 9.757729755661011e-05.
# Epoch 5/40
# 5022/5022 [==============================] - 876s 174ms/step - loss: 1.2150 - root_loss: 0.4482 - vowel_loss: 0.1633 - consonant_loss: 0.1552 - root_recall: 0.7991 - vowel_recall: 0.9360 - consonant_recall: 0.9081 - val_loss: 1.0799 - val_root_loss: 0.3618 - val_vowel_loss: 0.1528 - val_consonant_loss: 0.2036 - val_root_recall: 0.8477 - val_vowel_recall: 0.9426 - val_consonant_recall: 0.9047
#
# Epoch 00006: CosineAnnealingScheduler setting learning rate to 9.623203685930869e-05.
# Epoch 6/40
# 5022/5022 [==============================] - 873s 174ms/step - loss: 1.0378 - root_loss: 0.3773 - vowel_loss: 0.1422 - consonant_loss: 0.1411 - root_recall: 0.8296 - vowel_recall: 0.9451 - consonant_recall: 0.9185 - val_loss: 0.9463 - val_root_loss: 0.3339 - val_vowel_loss: 0.1338 - val_consonant_loss: 0.1447 - val_root_recall: 0.8718 - val_vowel_recall: 0.9405 - val_consonant_recall: 0.9255
#
# Epoch 00007: CosineAnnealingScheduler setting learning rate to 9.460482294732421e-05.
# Epoch 7/40
# 5022/5022 [==============================] - 879s 175ms/step - loss: 0.9000 - root_loss: 0.3233 - vowel_loss: 0.1278 - consonant_loss: 0.1256 - root_recall: 0.8520 - vowel_recall: 0.9509 - consonant_recall: 0.9272 - val_loss: 0.7882 - val_root_loss: 0.2879 - val_vowel_loss: 0.0958 - val_consonant_loss: 0.1166 - val_root_recall: 0.8840 - val_vowel_recall: 0.9645 - val_consonant_recall: 0.9426
#
# Epoch 00008: CosineAnnealingScheduler setting learning rate to 9.270568813552756e-05.
# Epoch 8/40
# 5022/5022 [==============================] - 893s 178ms/step - loss: 0.8112 - root_loss: 0.2901 - vowel_loss: 0.1172 - consonant_loss: 0.1138 - root_recall: 0.8682 - vowel_recall: 0.9553 - consonant_recall: 0.9345 - val_loss: 0.7285 - val_root_loss: 0.2618 - val_vowel_loss: 0.1041 - val_consonant_loss: 0.1009 - val_root_recall: 0.9023 - val_vowel_recall: 0.9611 - val_consonant_recall: 0.9603
#
# Epoch 00009: CosineAnnealingScheduler setting learning rate to 9.05463412215599e-05.
# Epoch 9/40
# 5022/5022 [==============================] - 904s 180ms/step - loss: 0.7265 - root_loss: 0.2615 - vowel_loss: 0.1036 - consonant_loss: 0.0998 - root_recall: 0.8796 - vowel_recall: 0.9603 - consonant_recall: 0.9402 - val_loss: 0.7242 - val_root_loss: 0.2685 - val_vowel_loss: 0.0862 - val_consonant_loss: 0.1009 - val_root_recall: 0.9056 - val_vowel_recall: 0.9747 - val_consonant_recall: 0.9551
#
# Epoch 00010: CosineAnnealingScheduler setting learning rate to 8.814009529720155e-05.
# Epoch 10/40
# 5022/5022 [==============================] - 907s 181ms/step - loss: 0.6587 - root_loss: 0.2351 - vowel_loss: 0.0950 - consonant_loss: 0.0935 - root_recall: 0.8900 - vowel_recall: 0.9637 - consonant_recall: 0.9437 - val_loss: 0.6851 - val_root_loss: 0.2477 - val_vowel_loss: 0.0876 - val_consonant_loss: 0.1022 - val_root_recall: 0.9162 - val_vowel_recall: 0.9734 - val_consonant_recall: 0.9545
#
# Epoch 00011: CosineAnnealingScheduler setting learning rate to 8.55017856687341e-05.
# Epoch 11/40
# 5022/5022 [==============================] - 910s 181ms/step - loss: 0.6044 - root_loss: 0.2099 - vowel_loss: 0.0897 - consonant_loss: 0.0950 - root_recall: 0.8999 - vowel_recall: 0.9665 - consonant_recall: 0.9449 - val_loss: 0.6558 - val_root_loss: 0.2387 - val_vowel_loss: 0.0787 - val_consonant_loss: 0.0997 - val_root_recall: 0.9140 - val_vowel_recall: 0.9756 - val_consonant_recall: 0.9663
#
# Epoch 00012: CosineAnnealingScheduler setting learning rate to 8.26476783923441e-05.
# Epoch 12/40
# 5022/5022 [==============================] - 913s 182ms/step - loss: 0.5517 - root_loss: 0.1935 - vowel_loss: 0.0797 - consonant_loss: 0.0850 - root_recall: 0.9073 - vowel_recall: 0.9692 - consonant_recall: 0.9497 - val_loss: 0.6366 - val_root_loss: 0.2286 - val_vowel_loss: 0.0803 - val_consonant_loss: 0.0991 - val_root_recall: 0.9298 - val_vowel_recall: 0.9783 - val_consonant_recall: 0.9617
#
# Epoch 00013: CosineAnnealingScheduler setting learning rate to 7.959536998847742e-05.
# Epoch 13/40
# 5022/5022 [==============================] - 888s 177ms/step - loss: 0.4816 - root_loss: 0.1710 - vowel_loss: 0.0722 - consonant_loss: 0.0673 - root_recall: 0.9169 - vowel_recall: 0.9723 - consonant_recall: 0.9560 - val_loss: 0.6432 - val_root_loss: 0.2316 - val_vowel_loss: 0.0842 - val_consonant_loss: 0.0958 - val_root_recall: 0.9224 - val_vowel_recall: 0.9773 - val_consonant_recall: 0.9720
#
# Epoch 00014: CosineAnnealingScheduler setting learning rate to 7.636367895343946e-05.
# Epoch 14/40
# 5022/5022 [==============================] - 878s 175ms/step - loss: 0.4593 - root_loss: 0.1592 - vowel_loss: 0.0695 - consonant_loss: 0.0714 - root_recall: 0.9211 - vowel_recall: 0.9727 - consonant_recall: 0.9572 - val_loss: 0.5964 - val_root_loss: 0.2187 - val_vowel_loss: 0.0704 - val_consonant_loss: 0.0885 - val_root_recall: 0.9348 - val_vowel_recall: 0.9793 - val_consonant_recall: 0.9636
#
# Epoch 00015: CosineAnnealingScheduler setting learning rate to 7.297252973710757e-05.
# Epoch 15/40
# 5022/5022 [==============================] - 893s 178ms/step - loss: 0.4234 - root_loss: 0.1472 - vowel_loss: 0.0637 - consonant_loss: 0.0654 - root_recall: 0.9268 - vowel_recall: 0.9756 - consonant_recall: 0.9603 - val_loss: 0.6406 - val_root_loss: 0.2321 - val_vowel_loss: 0.0843 - val_consonant_loss: 0.0921 - val_root_recall: 0.9298 - val_vowel_recall: 0.9812 - val_consonant_recall: 0.9714
#
# Epoch 00016: CosineAnnealingScheduler setting learning rate to 6.944282990207195e-05.
# Epoch 16/40
# 5022/5022 [==============================] - 903s 180ms/step - loss: 0.3678 - root_loss: 0.1286 - vowel_loss: 0.0567 - consonant_loss: 0.0539 - root_recall: 0.9355 - vowel_recall: 0.9778 - consonant_recall: 0.9643 - val_loss: 0.6436 - val_root_loss: 0.2323 - val_vowel_loss: 0.0798 - val_consonant_loss: 0.0993 - val_root_recall: 0.9310 - val_vowel_recall: 0.9793 - val_consonant_recall: 0.9707
#
# Epoch 00017: CosineAnnealingScheduler setting learning rate to 6.57963412215599e-05.
# Epoch 17/40
# 5022/5022 [==============================] - 910s 181ms/step - loss: 0.3351 - root_loss: 0.1171 - vowel_loss: 0.0516 - consonant_loss: 0.0492 - root_recall: 0.9399 - vowel_recall: 0.9793 - consonant_recall: 0.9672 - val_loss: 0.6328 - val_root_loss: 0.2189 - val_vowel_loss: 0.0775 - val_consonant_loss: 0.1175 - val_root_recall: 0.9351 - val_vowel_recall: 0.9785 - val_consonant_recall: 0.9710
#
# Epoch 00018: CosineAnnealingScheduler setting learning rate to 6.205554551086733e-05.
# Epoch 18/40
# 5022/5022 [==============================] - 911s 181ms/step - loss: 0.3109 - root_loss: 0.1047 - vowel_loss: 0.0481 - consonant_loss: 0.0534 - root_recall: 0.9452 - vowel_recall: 0.9809 - consonant_recall: 0.9668 - val_loss: 0.6104 - val_root_loss: 0.2196 - val_vowel_loss: 0.0765 - val_consonant_loss: 0.0947 - val_root_recall: 0.9334 - val_vowel_recall: 0.9797 - val_consonant_recall: 0.9724
#
# Epoch 00019: CosineAnnealingScheduler setting learning rate to 5.8243506019491436e-05.
# Epoch 19/40
# 2325/5022 [============>.................] - ETA: 7:35 - loss: 0.2800 - root_loss: 0.0978 - vowel_loss: 0.0420 - consonant_loss: 0.0424 - root_recall: 0.9493 - vowel_recall: 0.9832 - consonant_recall: 0.9702

# %%
model.optimizer.get_config()
# Out:
# {'amsgrad': False,
#  'beta_1': 0.9,
#  'beta_2': 0.999,
#  'decay': 0.0,
#  'epsilon': 1e-07,
#  'learning_rate': 1.6094272e-06,
#  'name': 'Adam'}

# %%
from matplotlib import pyplot as plt

# %%
# %matplotlib inline

plt.style.use('ggplot')
plt.figure()
plt.plot(np.arange(0, epochs), history.history['loss'], label='loss')
plt.plot(np.arange(0, epochs), history.history['val_loss'], label='val_loss')
plt.plot(np.arange(0, epochs), history.history['val_root_loss'], label='val_root_loss')
plt.plot(np.arange(0, epochs), history.history['val_vowel_loss'], label='val_vowel_loss')
plt.plot(np.arange(0, epochs), history.history['val_consonant_loss'], label='val_consonant_loss')

    
plt.title('loss')
plt.xlabel('Epoch #')
plt.ylabel('Loss')
plt.legend(loc='upper right')
plt.show()

# %%
plt.style.use('ggplot')
plt.figure()
plt.plot(np.arange(0, epochs), history.history['weighted_recall'], label='weighted_recall')
plt.plot(np.arange(0, epochs), history.history['val_root_recall'], label='val_root_recall')
plt.plot(np.arange(0, epochs), history.history['val_vowel_recall'], label='val_vowel_recall')
plt.plot(np.arange(0, epochs), history.history['val_consonant_recall'], label='val_consonant_recall')

    
plt.title('recall')
plt.xlabel('Epoch #')
plt.ylabel('Loss')
plt.legend(loc='upper right')
plt.show()

# %%
plt.style.use('ggplot')
plt.figure()
plt.plot(np.arange(0, epochs), history.history['lr'], label='lr')

    
plt.title('lr')
plt.xlabel('Epoch #')
plt.ylabel('Loss')
plt.legend(loc='upper right')
plt.show()

# %%
plt.style.use('ggplot')
plt.figure()
plt.plot(np.arange(0, epochs), history.history['weighted_recall'], label='w_recall')
plt.plot(np.arange(0, epochs), history.history['val_weighted_recall'], label='val_w_recall')
    
plt.title('recall')
plt.xlabel('Epoch #')
plt.ylabel('Loss')
plt.legend(loc='upper right')
plt.show()
