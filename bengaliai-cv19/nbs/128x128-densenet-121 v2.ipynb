# %%
# !ls
# Out:
# drive  sample_data  train

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !mkdir train

# %%
# !mkdir train/128

# %%
# !cp '/content/drive/My Drive/kaggle/bengali/input/grapheme-imgs-128x128.zip' train

# %%
# !cp '/content/drive/My Drive/kaggle/bengali/input/train.csv' train

# %%
#!cp '/content/drive/My Drive/kaggle/bengali/input/DenseNet-BC-121-32-no-top.h5' train

# %%
# !unzip train/grapheme-imgs-128x128.zip  -d train/128/

# %%
# !ls train
# Out:
# 128  grapheme-imgs-128x128.zip	train.csv

# %%
# %tensorflow_version 2.x
# Out:
# TensorFlow 2.x selected.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import cv2

import tensorflow as tf
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import LeakyReLU
from keras.layers.normalization import BatchNormalization
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.callbacks import ReduceLROnPlateau,LambdaCallback
from tensorflow.keras import layers


# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
#for dirname, _, filenames in os.walk('/kaggle/input'):
#    for filename in filenames:
#        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.
# Out:
# Using TensorFlow backend.

# %%
os.chdir('/content/')

# %%
dataset_np = pd.read_csv('./train/train.csv').to_numpy()
train_dir='./train/128'

# %%
dataset_np[:,0]+='.png'
dataset_m = dataset_np.shape[0]
split_rate = 0.1
valid_m = int(dataset_m*split_rate)
train_m = int(dataset_m-valid_m)
indicies=np.arange(dataset_m)
np.random.shuffle(indicies)
random_train_inds = indicies[0:train_m]
random_valid_inds = indicies[train_m:train_m+valid_m]
train_np = dataset_np[random_train_inds]
valid_np = dataset_np[random_valid_inds]
train_df = pd.DataFrame(train_np)
valid_df = pd.DataFrame(valid_np)
train_df.rename(columns={0:'filename',1:'root_class',2:'vowel_class',3:'cons_class', 4:'grapheme'}, inplace=True)
valid_df.rename(columns={0:'filename',1:'root_class',2:'vowel_class',3:'cons_class', 4:'grapheme'}, inplace=True)

# %%
def build_model(densenet):
    x_in = layers.Input(shape=(128, 128, 3))
    x = densenet(x_in)
    
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.5)(x)
    x = layers.Dense(256)(x)
    x = layers.LeakyReLU(alpha=0.1)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.5)(x)
    
    out_root = tf.keras.layers.Dense(168, activation='softmax', name='root')(x)
    out_vowel = tf.keras.layers.Dense(11, activation='softmax', name='vowel')(x)
    out_consonant = tf.keras.layers.Dense(7, activation='softmax', name='consonant')(x)
    
    model = tf.keras.Model(inputs=x_in, outputs=[out_root, out_vowel, out_consonant])
    
    return model

# %%
#densenet_weights = './train/DenseNet-BC-121-32-no-top.h5'
densenet = DenseNet121(include_top=False, weights=None, input_shape=(128, 128, 3))

# %%
model = build_model(densenet)

loss_dict={'root': 'categorical_crossentropy',
           'vowel':    'categorical_crossentropy',
           'consonant':'categorical_crossentropy'}
metrics_dict={ 'root':     [tf.keras.metrics.Recall(name='recall')],
               'vowel':    [tf.keras.metrics.Recall(name='recall')],
               'consonant':[tf.keras.metrics.Recall(name='recall')]}

initial_learningrate=1e-3
model.compile(optimizer='adam', loss=loss_dict, loss_weights=[2.0,1.0,1.0], 
                  metrics=metrics_dict)

# %%
tf.keras.utils.plot_model(model, to_file='model.png', show_shapes=True)

# %%
train_datagen = ImageDataGenerator(rotation_range = 10,
                                   shear_range = 0.1)

valid_datagen = ImageDataGenerator()

# %%
columns=["root_class","vowel_class", "cons_class"]
batch_size = 256
train_generator = train_datagen.flow_from_dataframe(
        dataframe=train_df,
        directory=train_dir,
        x_col="filename",
        y_col=columns,
        target_size=(128, 128),
        batch_size=batch_size,
        class_mode="multi_output",
        colormode="greyscale")

valid_generator = valid_datagen.flow_from_dataframe(
        dataframe=valid_df,
        directory=train_dir,
        x_col="filename",
        y_col=columns,
        target_size=(128, 128),
        batch_size=batch_size,
        class_mode="multi_output",
        colormode="greyscale")
# Out:
# Found 180756 validated image filenames.
# Found 20084 validated image filenames.

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 7482146634293133694, name: "/device:XLA_CPU:0"
#  device_type: "XLA_CPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 15733313381889724388
#  physical_device_desc: "device: XLA_CPU device", name: "/device:XLA_GPU:0"
#  device_type: "XLA_GPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 15020496341085366906
#  physical_device_desc: "device: XLA_GPU device", name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 15956161332
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 13458928638086368783
#  physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0"]

# %%
def split_into_3_outputs(y_batch):
    
    y1=tf.keras.utils.to_categorical(y_batch[0],168)
    y2=tf.keras.utils.to_categorical(y_batch[1],11)
    y3=tf.keras.utils.to_categorical(y_batch[2],7)
    
    return y1,y2,y3

# %%
def aux_data_gen(generator):
    stats = (0.0692, 0.2051)
    while True:
        batch = next(generator)
        batch_x = (batch[0].astype(np.float32)/255.0 - stats[0])/stats[1]
        yield batch_x, split_into_3_outputs(batch[1])

# %%
import math
from tensorflow.keras.callbacks import Callback
from tensorflow.keras import backend as K


class CosineAnnealingScheduler(Callback):
    """Cosine annealing scheduler.
    """

    def __init__(self, T_max, eta_max, eta_min=0, verbose=0):
        super(CosineAnnealingScheduler, self).__init__()
        self.T_max = T_max
        self.eta_max = eta_max
        self.eta_min = eta_min
        self.verbose = verbose

    def on_epoch_begin(self, epoch, logs=None):
        if not hasattr(self.model.optimizer, 'lr'):
            raise ValueError('Optimizer must have a "lr" attribute.')
        lr = self.eta_min + (self.eta_max - self.eta_min) * (1 + math.cos(math.pi * epoch / self.T_max)) / 2
        K.set_value(self.model.optimizer.lr, lr)
        if self.verbose > 0:
            print('\nEpoch %05d: CosineAnnealingScheduler setting learning '
                  'rate to %s.' % (epoch + 1, lr))

    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        logs['lr'] = K.get_value(self.model.optimizer.lr)

# %%
epochs = 20

ca_shed = CosineAnnealingScheduler(T_max=epochs, eta_max=1e-3, eta_min=1e-6,verbose=1)

history=model.fit_generator(aux_data_gen(train_generator),
                    validation_data=aux_data_gen(valid_generator),
                    epochs=epochs,
                    steps_per_epoch=train_m//batch_size+1,
                    validation_steps = valid_m//batch_size+1,
                    callbacks=[ca_shed])
# Out:
# Train for 707 steps, validate for 79 steps
#
# Epoch 00001: CosineAnnealingScheduler setting learning rate to 0.001.
# Epoch 1/20
# 707/707 [==============================] - 806s 1s/step - loss: 6.1225 - root_loss: 2.3837 - vowel_loss: 0.7188 - consonant_loss: 0.6362 - root_recall: 0.3111 - vowel_recall: 0.7131 - consonant_recall: 0.7480 - val_loss: 3.6834 - val_root_loss: 1.3866 - val_vowel_loss: 0.6221 - val_consonant_loss: 0.2880 - val_root_recall: 0.5320 - val_vowel_recall: 0.7734 - val_consonant_recall: 0.9085
#
# Epoch 00002: CosineAnnealingScheduler setting learning rate to 0.0009938503261272714.
# Epoch 2/20
# 707/707 [==============================] - 755s 1s/step - loss: 1.6510 - root_loss: 0.6054 - vowel_loss: 0.2334 - consonant_loss: 0.2067 - root_recall: 0.7743 - vowel_recall: 0.9209 - consonant_recall: 0.9328 - val_loss: 2.5145 - val_root_loss: 1.0894 - val_vowel_loss: 0.1610 - val_consonant_loss: 0.1747 - val_root_recall: 0.6727 - val_vowel_recall: 0.9485 - val_consonant_recall: 0.9434
#
# Epoch 00003: CosineAnnealingScheduler setting learning rate to 0.0009755527298894294.
# Epoch 3/20
# 707/707 [==============================] - 789s 1s/step - loss: 1.1733 - root_loss: 0.4252 - vowel_loss: 0.1661 - consonant_loss: 0.1567 - root_recall: 0.8520 - vowel_recall: 0.9477 - consonant_recall: 0.9516 - val_loss: 1.5959 - val_root_loss: 0.6334 - val_vowel_loss: 0.1417 - val_consonant_loss: 0.1875 - val_root_recall: 0.8148 - val_vowel_recall: 0.9567 - val_consonant_recall: 0.9422
#
# Epoch 00004: CosineAnnealingScheduler setting learning rate to 0.0009455577588320898.
# Epoch 4/20
# 707/707 [==============================] - 810s 1s/step - loss: 0.9839 - root_loss: 0.3567 - vowel_loss: 0.1385 - consonant_loss: 0.1319 - root_recall: 0.8792 - vowel_recall: 0.9590 - consonant_recall: 0.9604 - val_loss: 0.9925 - val_root_loss: 0.3804 - val_vowel_loss: 0.1219 - val_consonant_loss: 0.1098 - val_root_recall: 0.8814 - val_vowel_recall: 0.9639 - val_consonant_recall: 0.9656
#
# Epoch 00005: CosineAnnealingScheduler setting learning rate to 0.0009046039886902864.
# Epoch 5/20
# 707/707 [==============================] - 770s 1s/step - loss: 0.8328 - root_loss: 0.3003 - vowel_loss: 0.1197 - consonant_loss: 0.1124 - root_recall: 0.8990 - vowel_recall: 0.9662 - consonant_recall: 0.9669 - val_loss: 0.8786 - val_root_loss: 0.3411 - val_vowel_loss: 0.0959 - val_consonant_loss: 0.1005 - val_root_recall: 0.8864 - val_vowel_recall: 0.9715 - val_consonant_recall: 0.9695
#
# Epoch 00006: CosineAnnealingScheduler setting learning rate to 0.0008536998372026805.
# Epoch 6/20
# 707/707 [==============================] - 752s 1s/step - loss: 0.7450 - root_loss: 0.2669 - vowel_loss: 0.1075 - consonant_loss: 0.1037 - root_recall: 0.9115 - vowel_recall: 0.9700 - consonant_recall: 0.9701 - val_loss: 0.8532 - val_root_loss: 0.3319 - val_vowel_loss: 0.0979 - val_consonant_loss: 0.0914 - val_root_recall: 0.8924 - val_vowel_recall: 0.9718 - val_consonant_recall: 0.9713
#
# Epoch 00007: CosineAnnealingScheduler setting learning rate to 0.0007940987335200904.
# Epoch 7/20
# 707/707 [==============================] - 782s 1s/step - loss: 0.6483 - root_loss: 0.2331 - vowel_loss: 0.0934 - consonant_loss: 0.0888 - root_recall: 0.9230 - vowel_recall: 0.9746 - consonant_recall: 0.9744 - val_loss: 1.0241 - val_root_loss: 0.3971 - val_vowel_loss: 0.1247 - val_consonant_loss: 0.1051 - val_root_recall: 0.8857 - val_vowel_recall: 0.9656 - val_consonant_recall: 0.9710
#
# Epoch 00008: CosineAnnealingScheduler setting learning rate to 0.0007272682546199037.
# Epoch 8/20
# 707/707 [==============================] - 752s 1s/step - loss: 0.5864 - root_loss: 0.2098 - vowel_loss: 0.0850 - consonant_loss: 0.0817 - root_recall: 0.9310 - vowel_recall: 0.9775 - consonant_recall: 0.9768 - val_loss: 0.8149 - val_root_loss: 0.3268 - val_vowel_loss: 0.0821 - val_consonant_loss: 0.0792 - val_root_recall: 0.8972 - val_vowel_recall: 0.9780 - val_consonant_recall: 0.9750
#
# Epoch 00009: CosineAnnealingScheduler setting learning rate to 0.0006548539886902864.
# Epoch 9/20
# 707/707 [==============================] - 745s 1s/step - loss: 0.5192 - root_loss: 0.1844 - vowel_loss: 0.0760 - consonant_loss: 0.0745 - root_recall: 0.9399 - vowel_recall: 0.9800 - consonant_recall: 0.9794 - val_loss: 0.8614 - val_root_loss: 0.3441 - val_vowel_loss: 0.0927 - val_consonant_loss: 0.0804 - val_root_recall: 0.8974 - val_vowel_recall: 0.9744 - val_consonant_recall: 0.9764
#
# Epoch 00010: CosineAnnealingScheduler setting learning rate to 0.0005786390152875954.
# Epoch 10/20
# 707/707 [==============================] - 748s 1s/step - loss: 0.4534 - root_loss: 0.1602 - vowel_loss: 0.0681 - consonant_loss: 0.0649 - root_recall: 0.9477 - vowel_recall: 0.9827 - consonant_recall: 0.9826 - val_loss: 0.6308 - val_root_loss: 0.2389 - val_vowel_loss: 0.0758 - val_consonant_loss: 0.0772 - val_root_recall: 0.9266 - val_vowel_recall: 0.9807 - val_consonant_recall: 0.9767
#
# Epoch 00011: CosineAnnealingScheduler setting learning rate to 0.0005005000000000001.
# Epoch 11/20
# 707/707 [==============================] - 781s 1s/step - loss: 0.3968 - root_loss: 0.1397 - vowel_loss: 0.0586 - consonant_loss: 0.0587 - root_recall: 0.9538 - vowel_recall: 0.9854 - consonant_recall: 0.9840 - val_loss: 0.5952 - val_root_loss: 0.2306 - val_vowel_loss: 0.0665 - val_consonant_loss: 0.0675 - val_root_recall: 0.9300 - val_vowel_recall: 0.9830 - val_consonant_recall: 0.9819
#
# Epoch 00012: CosineAnnealingScheduler setting learning rate to 0.00042236098471240487.
# Epoch 12/20
# 707/707 [==============================] - 766s 1s/step - loss: 0.3401 - root_loss: 0.1179 - vowel_loss: 0.0527 - consonant_loss: 0.0515 - root_recall: 0.9613 - vowel_recall: 0.9868 - consonant_recall: 0.9861 - val_loss: 0.5197 - val_root_loss: 0.1993 - val_vowel_loss: 0.0582 - val_consonant_loss: 0.0627 - val_root_recall: 0.9459 - val_vowel_recall: 0.9845 - val_consonant_recall: 0.9844
#
# Epoch 00013: CosineAnnealingScheduler setting learning rate to 0.0003461460113097139.
# Epoch 13/20
# 707/707 [==============================] - 748s 1s/step - loss: 0.2793 - root_loss: 0.0958 - vowel_loss: 0.0436 - consonant_loss: 0.0440 - root_recall: 0.9687 - vowel_recall: 0.9893 - consonant_recall: 0.9886 - val_loss: 0.5547 - val_root_loss: 0.2077 - val_vowel_loss: 0.0718 - val_consonant_loss: 0.0676 - val_root_recall: 0.9415 - val_vowel_recall: 0.9832 - val_consonant_recall: 0.9827
#
# Epoch 00014: CosineAnnealingScheduler setting learning rate to 0.00027373174538009644.
# Epoch 14/20
# 707/707 [==============================] - 751s 1s/step - loss: 0.2328 - root_loss: 0.0794 - vowel_loss: 0.0369 - consonant_loss: 0.0372 - root_recall: 0.9741 - vowel_recall: 0.9910 - consonant_recall: 0.9907 - val_loss: 0.5143 - val_root_loss: 0.1893 - val_vowel_loss: 0.0697 - val_consonant_loss: 0.0660 - val_root_recall: 0.9490 - val_vowel_recall: 0.9819 - val_consonant_recall: 0.9827
#
# Epoch 00015: CosineAnnealingScheduler setting learning rate to 0.00020690126647990973.
# Epoch 15/20
# 707/707 [==============================] - 757s 1s/step - loss: 0.1901 - root_loss: 0.0623 - vowel_loss: 0.0328 - consonant_loss: 0.0328 - root_recall: 0.9796 - vowel_recall: 0.9923 - consonant_recall: 0.9921 - val_loss: 0.5023 - val_root_loss: 0.1885 - val_vowel_loss: 0.0637 - val_consonant_loss: 0.0617 - val_root_recall: 0.9510 - val_vowel_recall: 0.9871 - val_consonant_recall: 0.9854
#
# Epoch 00016: CosineAnnealingScheduler setting learning rate to 0.00014730016279731955.
# Epoch 16/20
# 707/707 [==============================] - 757s 1s/step - loss: 0.1567 - root_loss: 0.0508 - vowel_loss: 0.0284 - consonant_loss: 0.0266 - root_recall: 0.9835 - vowel_recall: 0.9934 - consonant_recall: 0.9932 - val_loss: 0.4888 - val_root_loss: 0.1841 - val_vowel_loss: 0.0589 - val_consonant_loss: 0.0617 - val_root_recall: 0.9518 - val_vowel_recall: 0.9865 - val_consonant_recall: 0.9846
#
# Epoch 00017: CosineAnnealingScheduler setting learning rate to 9.639601130971382e-05.
# Epoch 17/20
# 707/707 [==============================] - 745s 1s/step - loss: 0.1289 - root_loss: 0.0417 - vowel_loss: 0.0234 - consonant_loss: 0.0221 - root_recall: 0.9867 - vowel_recall: 0.9946 - consonant_recall: 0.9948 - val_loss: 0.4697 - val_root_loss: 0.1787 - val_vowel_loss: 0.0518 - val_consonant_loss: 0.0604 - val_root_recall: 0.9539 - val_vowel_recall: 0.9890 - val_consonant_recall: 0.9860
#
# Epoch 00018: CosineAnnealingScheduler setting learning rate to 5.544224116791029e-05.
# Epoch 18/20
# 707/707 [==============================] - 746s 1s/step - loss: 0.1052 - root_loss: 0.0331 - vowel_loss: 0.0201 - consonant_loss: 0.0189 - root_recall: 0.9895 - vowel_recall: 0.9956 - consonant_recall: 0.9955 - val_loss: 0.4564 - val_root_loss: 0.1734 - val_vowel_loss: 0.0523 - val_consonant_loss: 0.0573 - val_root_recall: 0.9577 - val_vowel_recall: 0.9897 - val_consonant_recall: 0.9863
#
# Epoch 00019: CosineAnnealingScheduler setting learning rate to 2.5447270110570814e-05.
# Epoch 19/20
# 707/707 [==============================] - 748s 1s/step - loss: 0.0932 - root_loss: 0.0291 - vowel_loss: 0.0185 - consonant_loss: 0.0165 - root_recall: 0.9913 - vowel_recall: 0.9960 - consonant_recall: 0.9962 - val_loss: 0.4681 - val_root_loss: 0.1765 - val_vowel_loss: 0.0578 - val_consonant_loss: 0.0573 - val_root_recall: 0.9556 - val_vowel_recall: 0.9880 - val_consonant_recall: 0.9866
#
# Epoch 00020: CosineAnnealingScheduler setting learning rate to 7.149673872728739e-06.
# Epoch 20/20
# 707/707 [==============================] - 748s 1s/step - loss: 0.0869 - root_loss: 0.0267 - vowel_loss: 0.0175 - consonant_loss: 0.0160 - root_recall: 0.9919 - vowel_recall: 0.9962 - consonant_recall: 0.9963 - val_loss: 0.4443 - val_root_loss: 0.1697 - val_vowel_loss: 0.0498 - val_consonant_loss: 0.0551 - val_root_recall: 0.9576 - val_vowel_recall: 0.9894 - val_consonant_recall: 0.9881

# %%
history.history['weighted_recall']= 0.5*np.array(history.history['root_recall'])+0.25*np.array(history.history['consonant_recall'])+0.25*np.array(history.history['vowel_recall'])
history.history['val_weighted_recall']= 0.5*np.array(history.history['val_root_recall'])+0.25*np.array(history.history['val_consonant_recall'])+0.25*np.array(history.history['val_vowel_recall'])

# %%
model.save_weights('/content/drive/My Drive/kaggle/bengali/output/w_dense_eps20_sr01_wop_adam.h5')
model.save("/content/drive/My Drive/kaggle/bengali/output/m_dense_eps20_sr01_wop_adam.h5")
pd.DataFrame(history.history).to_csv('/content/drive/My Drive/kaggle/bengali/output/h_dense_v2.csv', index=False)

# %%
model.optimizer.get_config()
# Out:
# {'centered': False,
#  'decay': 0.0,
#  'epsilon': 1e-07,
#  'learning_rate': 4.9387068e-06,
#  'momentum': 0.0,
#  'name': 'RMSprop',
#  'rho': 0.9}

# %%
from matplotlib import pyplot as plt

# %%
# %matplotlib inline

plt.style.use('ggplot')
plt.figure()
plt.plot(np.arange(0, epochs), history.history['loss'], label='loss')
plt.plot(np.arange(0, epochs), history.history['val_loss'], label='val_loss')
plt.plot(np.arange(0, epochs), history.history['val_root_loss'], label='val_root_loss')
plt.plot(np.arange(0, epochs), history.history['val_vowel_loss'], label='val_vowel_loss')
plt.plot(np.arange(0, epochs), history.history['val_consonant_loss'], label='val_consonant_loss')

    
plt.title('loss')
plt.xlabel('Epoch #')
plt.ylabel('Loss')
plt.legend(loc='upper right')
plt.show()

# %%
plt.style.use('ggplot')
plt.figure()
plt.plot(np.arange(0, epochs), history.history['weighted_recall'], label='weighted_recall')
plt.plot(np.arange(0, epochs), history.history['val_root_recall'], label='val_root_recall')
plt.plot(np.arange(0, epochs), history.history['val_vowel_recall'], label='val_vowel_recall')
plt.plot(np.arange(0, epochs), history.history['val_consonant_recall'], label='val_consonant_recall')

    
plt.title('recall')
plt.xlabel('Epoch #')
plt.ylabel('Loss')
plt.legend(loc='upper right')
plt.show()

# %%
plt.style.use('ggplot')
plt.figure()
plt.plot(np.arange(0, epochs), history.history['lr'], label='lr')

    
plt.title('lr')
plt.xlabel('Epoch #')
plt.ylabel('Loss')
plt.legend(loc='upper right')
plt.show()

# %%
plt.style.use('ggplot')
plt.figure()
plt.plot(np.arange(0, epochs), history.history['weighted_recall'], label='w_recall')
plt.plot(np.arange(0, epochs), history.history['val_weighted_recall'], label='val_w_recall')
    
plt.title('recall')
plt.xlabel('Epoch #')
plt.ylabel('Loss')
plt.legend(loc='upper right')
plt.show()
