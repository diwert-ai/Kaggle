# %%
# !ls
# Out:
# sample_data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !mkdir train

# %%
# !mkdir train/128

# %%
# !cp '/content/drive/My Drive/kaggle/bengali/input/grapheme-imgs-128x128.zip' train

# %%
# !cp '/content/drive/My Drive/kaggle/bengali/input/train.csv' train

# %%
# !cp '/content/drive/My Drive/kaggle/bengali/output/w_mishdense_ep16_sr01_bs32_adam_classweights.h5' train

# %%
#!cp '/content/drive/My Drive/kaggle/bengali/input/DenseNet-BC-121-32-no-top.h5' train

# %%
# !unzip train/grapheme-imgs-128x128.zip  -d train/128/

# %%
# !ls train
# Out:
# 128			   train.csv
# grapheme-imgs-128x128.zip  w_mishdense_ep16_sr01_bs32_adam_classweights.h5

# %%
# %tensorflow_version 2.x
# Out:
# TensorFlow 2.x selected.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import cv2
import math

import tensorflow as tf
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import LeakyReLU
from keras.layers.normalization import BatchNormalization
from tensorflow.keras.callbacks import ReduceLROnPlateau,LambdaCallback
from tensorflow.keras.applications.densenet import DenseNet121
from tensorflow.keras.models import load_model
from tensorflow.keras import layers
from tensorflow.keras.callbacks import Callback
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Activation
from tensorflow.keras.utils import get_custom_objects


# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
#for dirname, _, filenames in os.walk('/kaggle/input'):
#    for filename in filenames:
#        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.
# Out:
# Using TensorFlow backend.

# %%
dataset_np = pd.read_csv('./train/train.csv').to_numpy()
train_dir='./train/128'

# %%
dataset_np[:,0]+='.png'
dataset_m = dataset_np.shape[0]
split_rate = 0.1
valid_m = int(dataset_m*split_rate)
train_m = int(dataset_m-valid_m)
indicies=np.arange(dataset_m)
np.random.shuffle(indicies)
random_train_inds = indicies[0:train_m]
random_valid_inds = indicies[train_m:train_m+valid_m]
train_np = dataset_np[random_train_inds]
valid_np = dataset_np[random_valid_inds]
train_df = pd.DataFrame(train_np)
valid_df = pd.DataFrame(valid_np)
train_df.rename(columns={0:'filename',1:'root_class',2:'vowel_class',3:'cons_class', 4:'grapheme'}, inplace=True)
valid_df.rename(columns={0:'filename',1:'root_class',2:'vowel_class',3:'cons_class', 4:'grapheme'}, inplace=True)

# %%
cons_unique=np.unique(train_np[:,3])
cons_y_train = train_np[:,3]
vowel_unique=np.unique(train_np[:,2])
vowel_y_train = train_np[:,2]
root_unique =np.unique(train_np[:,1])
root_y_train = train_np[:,1]

# %%
from sklearn.utils import class_weight
cons_class_weights = class_weight.compute_class_weight('balanced',
                                                 cons_unique,
                                                 cons_y_train)

# %%
vowel_class_weights = class_weight.compute_class_weight('balanced',
                                                 vowel_unique,
                                                 vowel_y_train)

root_class_weights = class_weight.compute_class_weight('balanced',
                                                 root_unique,
                                                 root_y_train)

# %%
cons_cw_dict=dict(enumerate(cons_class_weights))
vowel_cw_dict=dict(enumerate(vowel_class_weights))
root_cw_dict=dict(enumerate(root_class_weights))

# %%
model_cw={}
model_cw['root']=root_cw_dict
model_cw['vowel']=vowel_cw_dict
model_cw['consonant']=cons_cw_dict

# %%
class Mish(Activation):
    '''
    Mish Activation Function.
    .. math::
        mish(x) = x * tanh(softplus(x)) = x * tanh(ln(1 + e^{x}))
    Shape:
        - Input: Arbitrary. Use the keyword argument `input_shape`
        (tuple of integers, does not include the samples axis)
        when using this layer as the first layer in a model.
        - Output: Same shape as the input.
    Examples:
        >>> X = Activation('Mish', name="conv1_act")(X_input)
    '''

    def __init__(self, activation, **kwargs):
        super(Mish, self).__init__(activation, **kwargs)
        self.__name__ = 'Mish'


def mish(inputs):
    return inputs * tf.math.tanh(tf.math.softplus(inputs))

get_custom_objects().update({'Mish': Mish(mish)})

# %%
#densenet_weights = './train/DenseNet-BC-121-32-no-top.h5'
densenet = DenseNet121(include_top=False, weights=None, input_shape=(128, 128, 3))

# %%
def build_head(x_in, n, name=None):
  x = layers.GlobalAveragePooling2D()(x_in)
  x = Activation('Mish', name='mish_act1_'+name) (x)
  x = layers.BatchNormalization()(x)
  x = layers.Dropout(0.5)(x)
  x = layers.Dense(512)(x)
  x = Activation('Mish', name='mish_act2_'+name) (x)
  x = layers.BatchNormalization()(x)
  x = layers.Dropout(0.5)(x)
  x = layers.Dense(n, name=name, activation='softmax')(x)
  return x

# %%
def build_model(densenet):
    x_in = layers.Input(shape=(128, 128, 3))
    x = densenet(x_in)
    out_root = build_head(x, 168,'root')
    out_vowel = build_head(x, 11,'vowel')
    out_consonant = build_head(x,7,'consonant')
    
    model = tf.keras.Model(inputs=x_in, outputs=[out_root, out_vowel, out_consonant])
    
    return model

# %%
model = build_model(densenet)

# %%
for (n, layer) in enumerate(model.layers[1].layers):
  if 'activation' in layer.get_config() and layer.get_config()['activation'] == 'relu':
        #print('replacing #{}: {}, {}'.format(n, layer, layer.activation))
        layer.activation = Mish(mish)
        #print('-> {}'.format(layer.activation))

# %%
import tempfile

def apply_modifications(model, custom_objects=None):
    """Applies modifications to the model layers to create a new Graph. For example, simply changing
    `model.layers[idx].activation = new activation` does not change the graph. The entire graph needs to be updated
    with modified inbound and outbound tensors because of change in layer building function.
    Args:
        model: The `keras.models.Model` instance.
    Returns:
        The modified model with changes applied. Does not mutate the original `model`.
    """
    # The strategy is to save the modified model and load it back. This is done because setting the activation
    # in a Keras layer doesnt actually change the graph. We have to iterate the entire graph and change the
    # layer inbound and outbound nodes with modified tensors. This is doubly complicated in Keras 2.x since
    # multiple inbound and outbound nodes are allowed with the Graph API.
    model_path = os.path.join(tempfile.gettempdir(), next(tempfile._get_candidate_names()) + '.h5')
    try:
        model.save(model_path)
        return load_model(model_path, custom_objects=custom_objects)
    finally:
        os.remove(model_path)

# %%
model = apply_modifications(model, custom_objects={'mish':Mish(mish)})
# Out:
# WARNING:tensorflow:No training configuration found in save file: the model was *not* compiled. Compile it manually.

# %%
loss_dict={'root': 'categorical_crossentropy',
           'vowel':    'categorical_crossentropy',
           'consonant':'categorical_crossentropy'}
           
metrics_dict={ 'root':     [tf.keras.metrics.Recall(name='recall')],
               'vowel':    [tf.keras.metrics.Recall(name='recall')],
              'consonant': [tf.keras.metrics.Recall(name='recall')]}

#metrics_dict={ 'root':     ['accuracy'],
#               'vowel':    ['accuracy'],
#               'consonant':['accuracy']}

initial_learningrate=1e-3
model.compile(optimizer='adam', loss=loss_dict, loss_weights=[2.0,1.0,1.0], 
                  metrics=metrics_dict)

# %%
#tf.keras.utils.plot_model(model, to_file='model.png', show_shapes=True)

# %%
train_datagen = ImageDataGenerator(rotation_range = 10,
                                   shear_range = 0.1)

valid_datagen = ImageDataGenerator()

# %%
columns=["root_class","vowel_class", "cons_class"]
batch_size = 32
train_generator = train_datagen.flow_from_dataframe(
        dataframe=train_df,
        directory=train_dir,
        x_col="filename",
        y_col=columns,
        target_size=(128, 128),
        batch_size=batch_size,
        class_mode="multi_output",
        colormode="greyscale")

valid_generator = valid_datagen.flow_from_dataframe(
        dataframe=valid_df,
        directory=train_dir,
        x_col="filename",
        y_col=columns,
        target_size=(128, 128),
        batch_size=batch_size,
        class_mode="multi_output",
        colormode="greyscale")
# Out:
# Found 180756 validated image filenames.
# Found 20084 validated image filenames.

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 4571028649380096305, name: "/device:XLA_CPU:0"
#  device_type: "XLA_CPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 4264528324076765326
#  physical_device_desc: "device: XLA_CPU device", name: "/device:XLA_GPU:0"
#  device_type: "XLA_GPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 768021361690822367
#  physical_device_desc: "device: XLA_GPU device", name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 15956161332
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 17223201188107374451
#  physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0"]

# %%
def split_into_3_outputs(y_batch):
    
    y1=tf.keras.utils.to_categorical(y_batch[0],168)
    y2=tf.keras.utils.to_categorical(y_batch[1],11)
    y3=tf.keras.utils.to_categorical(y_batch[2],7)
    
    return y1,y2,y3

# %%
def aux_data_gen(generator):
    stats = (0.0692, 0.2051)
    while True:
        batch = next(generator)
        batch_x = (batch[0].astype(np.float32)/255.0 - stats[0])/stats[1]
        yield batch_x, split_into_3_outputs(batch[1])

# %%
class CosineAnnealingScheduler(Callback):
    """Cosine annealing scheduler.
    """

    def __init__(self, T_max, eta_max, eta_min=0, verbose=0):
        super(CosineAnnealingScheduler, self).__init__()
        self.T_max = T_max
        self.eta_max = eta_max
        self.eta_min = eta_min
        self.verbose = verbose

    def on_epoch_begin(self, epoch, logs=None):
        if not hasattr(self.model.optimizer, 'lr'):
            raise ValueError('Optimizer must have a "lr" attribute.')
        lr = self.eta_min + (self.eta_max - self.eta_min) * (1 + math.cos(math.pi * epoch / self.T_max)) / 2
        K.set_value(self.model.optimizer.lr, lr)
        if self.verbose > 0:
            print('\nEpoch %05d: CosineAnnealingScheduler setting learning '
                  'rate to %s.' % (epoch + 1, lr))

    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        logs['lr'] = K.get_value(self.model.optimizer.lr)

# %%
model.load_weights('train/w_mishdense_ep16_sr01_bs32_adam_classweights.h5')

# %%
epochs = 20

ca_shed = CosineAnnealingScheduler(T_max=epochs, eta_max=1e-3, eta_min=1e-6,verbose=1)

history=model.fit_generator(aux_data_gen(train_generator),
                    validation_data=aux_data_gen(valid_generator),
                    epochs=epochs,
                    steps_per_epoch=train_m//batch_size+1,
                    validation_steps = valid_m//batch_size+1,
                    callbacks=[ca_shed],
                    class_weight=model_cw)

history.history['weighted_recall']= 0.5*np.array(history.history['root_recall'])+0.25*np.array(history.history['consonant_recall'])+0.25*np.array(history.history['vowel_recall'])
history.history['val_weighted_recall']= 0.5*np.array(history.history['val_root_recall'])+0.25*np.array(history.history['val_consonant_recall'])+0.25*np.array(history.history['val_vowel_recall'])

model.save_weights('/content/drive/My Drive/kaggle/bengali/output/w_mishdense_ep16_20_sr01_bs32_adam_classweights.h5')
model.save("/content/drive/My Drive/kaggle/bengali/output/m_mishdense_eps16_20_sr01_bs32_adam_classweights.h5")
pd.DataFrame(history.history).to_csv('/content/drive/My Drive/kaggle/bengali/output/h_mishdense_ep16_20_sr01_bs32_adam_classweights.csv', index=False)
# Out:
# WARNING:tensorflow:From <ipython-input-36-4c84bd822121>:11: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Train for 5649 steps, validate for 628 steps
#
# Epoch 00001: CosineAnnealingScheduler setting learning rate to 0.001.
# Epoch 1/20
# 5649/5649 [==============================] - 969s 172ms/step - loss: 0.7480 - root_loss: 0.2582 - vowel_loss: 0.1039 - consonant_loss: 0.1277 - root_recall: 0.8915 - vowel_recall: 0.9637 - consonant_recall: 0.9419 - val_loss: 0.4793 - val_root_loss: 0.1493 - val_vowel_loss: 0.0705 - val_consonant_loss: 0.1103 - val_root_recall: 0.9345 - val_vowel_recall: 0.9743 - val_consonant_recall: 0.9682
#
# Epoch 00002: CosineAnnealingScheduler setting learning rate to 0.0009938503261272714.
# Epoch 2/20
# 5649/5649 [==============================] - 945s 167ms/step - loss: 0.7825 - root_loss: 0.2619 - vowel_loss: 0.1048 - consonant_loss: 0.1540 - root_recall: 0.8864 - vowel_recall: 0.9626 - consonant_recall: 0.9356 - val_loss: 0.4834 - val_root_loss: 0.1618 - val_vowel_loss: 0.0724 - val_consonant_loss: 0.0873 - val_root_recall: 0.9311 - val_vowel_recall: 0.9784 - val_consonant_recall: 0.9709
#
# Epoch 00003: CosineAnnealingScheduler setting learning rate to 0.0009755527298894294.
# Epoch 3/20
# 5649/5649 [==============================] - 941s 166ms/step - loss: 0.6951 - root_loss: 0.2335 - vowel_loss: 0.0972 - consonant_loss: 0.1309 - root_recall: 0.8975 - vowel_recall: 0.9662 - consonant_recall: 0.9415 - val_loss: 0.5211 - val_root_loss: 0.1557 - val_vowel_loss: 0.0722 - val_consonant_loss: 0.1376 - val_root_recall: 0.9367 - val_vowel_recall: 0.9754 - val_consonant_recall: 0.9666
#
# Epoch 00004: CosineAnnealingScheduler setting learning rate to 0.0009455577588320898.
# Epoch 4/20
# 5649/5649 [==============================] - 938s 166ms/step - loss: 0.6857 - root_loss: 0.2264 - vowel_loss: 0.0962 - consonant_loss: 0.1368 - root_recall: 0.9005 - vowel_recall: 0.9663 - consonant_recall: 0.9411 - val_loss: 0.5562 - val_root_loss: 0.1685 - val_vowel_loss: 0.0773 - val_consonant_loss: 0.1418 - val_root_recall: 0.9365 - val_vowel_recall: 0.9743 - val_consonant_recall: 0.9679
#
# Epoch 00005: CosineAnnealingScheduler setting learning rate to 0.0009046039886902864.
# Epoch 5/20
# 5649/5649 [==============================] - 939s 166ms/step - loss: 0.6019 - root_loss: 0.2035 - vowel_loss: 0.0867 - consonant_loss: 0.1082 - root_recall: 0.9104 - vowel_recall: 0.9692 - consonant_recall: 0.9478 - val_loss: 0.4912 - val_root_loss: 0.1611 - val_vowel_loss: 0.0767 - val_consonant_loss: 0.0923 - val_root_recall: 0.9321 - val_vowel_recall: 0.9776 - val_consonant_recall: 0.9700
#
# Epoch 00006: CosineAnnealingScheduler setting learning rate to 0.0008536998372026805.
# Epoch 6/20
# 5649/5649 [==============================] - 936s 166ms/step - loss: 0.5418 - root_loss: 0.1842 - vowel_loss: 0.0782 - consonant_loss: 0.0952 - root_recall: 0.9162 - vowel_recall: 0.9729 - consonant_recall: 0.9522 - val_loss: 0.4888 - val_root_loss: 0.1518 - val_vowel_loss: 0.0740 - val_consonant_loss: 0.1112 - val_root_recall: 0.9404 - val_vowel_recall: 0.9766 - val_consonant_recall: 0.9703
#
# Epoch 00007: CosineAnnealingScheduler setting learning rate to 0.0007940987335200904.
# Epoch 7/20
# 5649/5649 [==============================] - 938s 166ms/step - loss: 0.4838 - root_loss: 0.1658 - vowel_loss: 0.0716 - consonant_loss: 0.0807 - root_recall: 0.9245 - vowel_recall: 0.9759 - consonant_recall: 0.9584 - val_loss: 0.5308 - val_root_loss: 0.1602 - val_vowel_loss: 0.0737 - val_consonant_loss: 0.1366 - val_root_recall: 0.9364 - val_vowel_recall: 0.9801 - val_consonant_recall: 0.9703
#
# Epoch 00008: CosineAnnealingScheduler setting learning rate to 0.0007272682546199037.
# Epoch 8/20
# 5649/5649 [==============================] - 935s 165ms/step - loss: 0.4472 - root_loss: 0.1491 - vowel_loss: 0.0652 - consonant_loss: 0.0838 - root_recall: 0.9302 - vowel_recall: 0.9772 - consonant_recall: 0.9587 - val_loss: 0.5132 - val_root_loss: 0.1521 - val_vowel_loss: 0.0721 - val_consonant_loss: 0.1369 - val_root_recall: 0.9450 - val_vowel_recall: 0.9799 - val_consonant_recall: 0.9741
#
# Epoch 00009: CosineAnnealingScheduler setting learning rate to 0.0006548539886902864.
# Epoch 9/20
# 5649/5649 [==============================] - 938s 166ms/step - loss: 0.3782 - root_loss: 0.1280 - vowel_loss: 0.0567 - consonant_loss: 0.0655 - root_recall: 0.9403 - vowel_recall: 0.9802 - consonant_recall: 0.9641 - val_loss: 0.5014 - val_root_loss: 0.1444 - val_vowel_loss: 0.0606 - val_consonant_loss: 0.1520 - val_root_recall: 0.9494 - val_vowel_recall: 0.9830 - val_consonant_recall: 0.9724
#
# Epoch 00010: CosineAnnealingScheduler setting learning rate to 0.0005786390152875954.
# Epoch 10/20
# 5649/5649 [==============================] - 961s 170ms/step - loss: 0.3406 - root_loss: 0.1144 - vowel_loss: 0.0520 - consonant_loss: 0.0598 - root_recall: 0.9453 - vowel_recall: 0.9817 - consonant_recall: 0.9668 - val_loss: 0.6439 - val_root_loss: 0.1810 - val_vowel_loss: 0.0791 - val_consonant_loss: 0.2029 - val_root_recall: 0.9353 - val_vowel_recall: 0.9807 - val_consonant_recall: 0.9522
#
# Epoch 00011: CosineAnnealingScheduler setting learning rate to 0.0005005000000000001.
# Epoch 11/20
# 5649/5649 [==============================] - 954s 169ms/step - loss: 0.3052 - root_loss: 0.1049 - vowel_loss: 0.0448 - consonant_loss: 0.0507 - root_recall: 0.9497 - vowel_recall: 0.9844 - consonant_recall: 0.9708 - val_loss: 0.4977 - val_root_loss: 0.1544 - val_vowel_loss: 0.0668 - val_consonant_loss: 0.1220 - val_root_recall: 0.9512 - val_vowel_recall: 0.9825 - val_consonant_recall: 0.9764
#
# Epoch 00012: CosineAnnealingScheduler setting learning rate to 0.00042236098471240487.
# Epoch 12/20
# 5649/5649 [==============================] - 943s 167ms/step - loss: 0.2579 - root_loss: 0.0869 - vowel_loss: 0.0381 - consonant_loss: 0.0459 - root_recall: 0.9564 - vowel_recall: 0.9866 - consonant_recall: 0.9742 - val_loss: 0.5129 - val_root_loss: 0.1552 - val_vowel_loss: 0.0696 - val_consonant_loss: 0.1329 - val_root_recall: 0.9542 - val_vowel_recall: 0.9852 - val_consonant_recall: 0.9750
#
# Epoch 00013: CosineAnnealingScheduler setting learning rate to 0.0003461460113097139.
# Epoch 13/20
# 5649/5649 [==============================] - 946s 168ms/step - loss: 0.2179 - root_loss: 0.0732 - vowel_loss: 0.0350 - consonant_loss: 0.0366 - root_recall: 0.9625 - vowel_recall: 0.9876 - consonant_recall: 0.9766 - val_loss: 0.5478 - val_root_loss: 0.1570 - val_vowel_loss: 0.0646 - val_consonant_loss: 0.1692 - val_root_recall: 0.9532 - val_vowel_recall: 0.9820 - val_consonant_recall: 0.9774
#
# Epoch 00014: CosineAnnealingScheduler setting learning rate to 0.00027373174538009644.
# Epoch 14/20
# 5649/5649 [==============================] - 944s 167ms/step - loss: 0.1879 - root_loss: 0.0611 - vowel_loss: 0.0300 - consonant_loss: 0.0358 - root_recall: 0.9676 - vowel_recall: 0.9889 - consonant_recall: 0.9779 - val_loss: 0.5250 - val_root_loss: 0.1608 - val_vowel_loss: 0.0730 - val_consonant_loss: 0.1304 - val_root_recall: 0.9556 - val_vowel_recall: 0.9841 - val_consonant_recall: 0.9788
#
# Epoch 00015: CosineAnnealingScheduler setting learning rate to 0.00020690126647990973.
# Epoch 15/20
# 5649/5649 [==============================] - 945s 167ms/step - loss: 0.1558 - root_loss: 0.0518 - vowel_loss: 0.0244 - consonant_loss: 0.0279 - root_recall: 0.9722 - vowel_recall: 0.9909 - consonant_recall: 0.9811 - val_loss: 0.5593 - val_root_loss: 0.1705 - val_vowel_loss: 0.0723 - val_consonant_loss: 0.1461 - val_root_recall: 0.9574 - val_vowel_recall: 0.9849 - val_consonant_recall: 0.9794
#
# Epoch 00016: CosineAnnealingScheduler setting learning rate to 0.00014730016279731955.
# Epoch 16/20
# 5649/5649 [==============================] - 946s 167ms/step - loss: 0.1345 - root_loss: 0.0438 - vowel_loss: 0.0224 - consonant_loss: 0.0245 - root_recall: 0.9755 - vowel_recall: 0.9914 - consonant_recall: 0.9829 - val_loss: 0.5275 - val_root_loss: 0.1542 - val_vowel_loss: 0.0743 - val_consonant_loss: 0.1449 - val_root_recall: 0.9593 - val_vowel_recall: 0.9853 - val_consonant_recall: 0.9800
#
# Epoch 00017: CosineAnnealingScheduler setting learning rate to 9.639601130971382e-05.
# Epoch 17/20
# 5649/5649 [==============================] - 946s 167ms/step - loss: 0.1125 - root_loss: 0.0363 - vowel_loss: 0.0193 - consonant_loss: 0.0206 - root_recall: 0.9791 - vowel_recall: 0.9925 - consonant_recall: 0.9849 - val_loss: 0.5604 - val_root_loss: 0.1664 - val_vowel_loss: 0.0720 - val_consonant_loss: 0.1557 - val_root_recall: 0.9603 - val_vowel_recall: 0.9867 - val_consonant_recall: 0.9815
#
# Epoch 00018: CosineAnnealingScheduler setting learning rate to 5.544224116791029e-05.
# Epoch 18/20
# 5649/5649 [==============================] - 947s 168ms/step - loss: 0.1052 - root_loss: 0.0335 - vowel_loss: 0.0181 - consonant_loss: 0.0201 - root_recall: 0.9809 - vowel_recall: 0.9932 - consonant_recall: 0.9858 - val_loss: 0.5867 - val_root_loss: 0.1817 - val_vowel_loss: 0.0730 - val_consonant_loss: 0.1503 - val_root_recall: 0.9602 - val_vowel_recall: 0.9874 - val_consonant_recall: 0.9821
#
# Epoch 00019: CosineAnnealingScheduler setting learning rate to 2.5447270110570814e-05.
# Epoch 19/20
# 5649/5649 [==============================] - 948s 168ms/step - loss: 0.0951 - root_loss: 0.0302 - vowel_loss: 0.0168 - consonant_loss: 0.0178 - root_recall: 0.9826 - vowel_recall: 0.9932 - consonant_recall: 0.9867 - val_loss: 0.5765 - val_root_loss: 0.1670 - val_vowel_loss: 0.0762 - val_consonant_loss: 0.1663 - val_root_recall: 0.9612 - val_vowel_recall: 0.9868 - val_consonant_recall: 0.9817
#
# Epoch 00020: CosineAnnealingScheduler setting learning rate to 7.149673872728739e-06.
# Epoch 20/20
# 5649/5649 [==============================] - 949s 168ms/step - loss: 0.0892 - root_loss: 0.0281 - vowel_loss: 0.0156 - consonant_loss: 0.0175 - root_recall: 0.9830 - vowel_recall: 0.9937 - consonant_recall: 0.9868 - val_loss: 0.5446 - val_root_loss: 0.1698 - val_vowel_loss: 0.0745 - val_consonant_loss: 0.1305 - val_root_recall: 0.9616 - val_vowel_recall: 0.9872 - val_consonant_recall: 0.9828

# %%
model.optimizer.get_config()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9b0cd75bc981> in <module>()
# ----> 1 model.optimizer.get_config()
#
# NameError: name 'model' is not defined

# %%
from matplotlib import pyplot as plt

# %%
# %matplotlib inline

plt.style.use('ggplot')
plt.figure()
plt.plot(np.arange(0, epochs), history.history['loss'], label='loss')
plt.plot(np.arange(0, epochs), history.history['val_loss'], label='val_loss')
plt.plot(np.arange(0, epochs), history.history['val_root_loss'], label='val_root_loss')
plt.plot(np.arange(0, epochs), history.history['val_vowel_loss'], label='val_vowel_loss')
plt.plot(np.arange(0, epochs), history.history['val_consonant_loss'], label='val_consonant_loss')

    
plt.title('loss')
plt.xlabel('Epoch #')
plt.ylabel('Loss')
plt.legend(loc='upper right')
plt.show()

# %%
plt.style.use('ggplot')
plt.figure()
plt.plot(np.arange(0, epochs), history.history['weighted_recall'], label='weighted_recall')
plt.plot(np.arange(0, epochs), history.history['val_root_recall'], label='val_root_recall')
plt.plot(np.arange(0, epochs), history.history['val_vowel_recall'], label='val_vowel_recall')
plt.plot(np.arange(0, epochs), history.history['val_consonant_recall'], label='val_consonant_recall')

    
plt.title('recall')
plt.xlabel('Epoch #')
plt.ylabel('Loss')
plt.legend(loc='upper right')
plt.show()

# %%
plt.style.use('ggplot')
plt.figure()
plt.plot(np.arange(0, epochs), history.history['lr'], label='lr')

    
plt.title('lr')
plt.xlabel('Epoch #')
plt.ylabel('Loss')
plt.legend(loc='upper right')
plt.show()

# %%
plt.style.use('ggplot')
plt.figure()
plt.plot(np.arange(0, epochs), history.history['weighted_recall'], label='w_recall')
plt.plot(np.arange(0, epochs), history.history['val_weighted_recall'], label='val_w_recall')
    
plt.title('recall')
plt.xlabel('Epoch #')
plt.ylabel('Loss')
plt.legend(loc='upper right')
plt.show()
