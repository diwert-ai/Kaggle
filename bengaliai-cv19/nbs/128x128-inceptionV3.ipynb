# %%
# !ls
# Out:
# drive  model.png  sample_data  train

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !mkdir train

# %%
# !mkdir train/128

# %%
# !cp '/content/drive/My Drive/kaggle/bengali/input/grapheme-imgs-128x128.zip' train

# %%
# !cp '/content/drive/My Drive/kaggle/bengali/input/train.csv' train

# %%
#!cp '/content/drive/My Drive/kaggle/bengali/input/DenseNet-BC-121-32-no-top.h5' train

# %%
# !unzip train/grapheme-imgs-128x128.zip  -d train/128/

# %%
# !ls train
# Out:
# 128  grapheme-imgs-128x128.zip	train.csv

# %%
# %tensorflow_version 2.x
# Out:
# TensorFlow 2.x selected.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import cv2

import tensorflow as tf
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import LeakyReLU
from keras.layers.normalization import BatchNormalization
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.callbacks import ReduceLROnPlateau,LambdaCallback
from tensorflow.keras import layers


# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
#for dirname, _, filenames in os.walk('/kaggle/input'):
#    for filename in filenames:
#        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.

# %%
os.chdir('/content/')

# %%
dataset_np = pd.read_csv('./train/train.csv').to_numpy()
train_dir='./train/128'

# %%
dataset_np[:,0]+='.png'
dataset_m = dataset_np.shape[0]
split_rate = 0.1
valid_m = int(dataset_m*split_rate)
train_m = int(dataset_m-valid_m)
indicies=np.arange(dataset_m)
np.random.shuffle(indicies)
random_train_inds = indicies[0:train_m]
random_valid_inds = indicies[train_m:train_m+valid_m]
train_np = dataset_np[random_train_inds]
valid_np = dataset_np[random_valid_inds]
train_df = pd.DataFrame(train_np)
valid_df = pd.DataFrame(valid_np)
train_df.rename(columns={0:'filename',1:'root_class',2:'vowel_class',3:'cons_class', 4:'grapheme'}, inplace=True)
valid_df.rename(columns={0:'filename',1:'root_class',2:'vowel_class',3:'cons_class', 4:'grapheme'}, inplace=True)

# %%
inceptionV3 = InceptionV3(include_top=False, weights=None, input_shape=(128, 128, 3))

# %%
def build_model(inceptionV3):
    x_in = layers.Input(shape=(128, 128, 3))
    x = inceptionV3(x_in)
    
    #x = layers.GlobalAveragePooling2D()(x)
    x = layers.Flatten()(x)
    x = layers.Dense(1024)(x)
    x = layers.LeakyReLU(alpha=0.1)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.5)(x)
    
    out_root = tf.keras.layers.Dense(168, activation='softmax', name='root')(x)
    out_vowel = tf.keras.layers.Dense(11, activation='softmax', name='vowel')(x)
    out_consonant = tf.keras.layers.Dense(7, activation='softmax', name='consonant')(x)
    
    model = tf.keras.Model(inputs=x_in, outputs=[out_root, out_vowel, out_consonant])
    
    return model

# %%
model = build_model(inceptionV3)

loss_dict={'root': 'categorical_crossentropy',
           'vowel':    'categorical_crossentropy',
           'consonant':'categorical_crossentropy'}
metrics_dict={ 'root':     [tf.keras.metrics.Recall(name='recall')],
               'vowel':    [tf.keras.metrics.Recall(name='recall')],
               'consonant':[tf.keras.metrics.Recall(name='recall')]}

initial_learningrate=1e-3
model.compile(optimizer=RMSprop(lr=initial_learningrate), loss=loss_dict, loss_weights=[2.0,1.0,1.0], 
                  metrics=metrics_dict)

# %%
tf.keras.utils.plot_model(model, to_file='model.png', show_shapes=True)

# %%
train_datagen = ImageDataGenerator(rotation_range = 10,
                                   shear_range = 0.1)

valid_datagen = ImageDataGenerator()

# %%
columns=["root_class","vowel_class", "cons_class"]
batch_size = 128
train_generator = train_datagen.flow_from_dataframe(
        dataframe=train_df,
        directory=train_dir,
        x_col="filename",
        y_col=columns,
        target_size=(128, 128),
        batch_size=batch_size,
        class_mode="multi_output",
        colormode="greyscale")

valid_generator = valid_datagen.flow_from_dataframe(
        dataframe=valid_df,
        directory=train_dir,
        x_col="filename",
        y_col=columns,
        target_size=(128, 128),
        batch_size=batch_size,
        class_mode="multi_output",
        colormode="greyscale")
# Out:
# Found 180756 validated image filenames.
# Found 20084 validated image filenames.

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 6203235280952614948, name: "/device:XLA_CPU:0"
#  device_type: "XLA_CPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 13228523399185514239
#  physical_device_desc: "device: XLA_CPU device", name: "/device:XLA_GPU:0"
#  device_type: "XLA_GPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 3985994277843435008
#  physical_device_desc: "device: XLA_GPU device", name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 15956161332
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 184808855800777429
#  physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0"]

# %%
def split_into_3_outputs(y_batch):
    
    y1=tf.keras.utils.to_categorical(y_batch[0],168)
    y2=tf.keras.utils.to_categorical(y_batch[1],11)
    y3=tf.keras.utils.to_categorical(y_batch[2],7)
    
    return y1,y2,y3

# %%
def aux_data_gen(generator):
    stats = (0.0692, 0.2051)
    while True:
        batch = next(generator)
        batch_x = (batch[0].astype(np.float32)/255.0 - stats[0])/stats[1]
        yield batch_x, split_into_3_outputs(batch[1])

# %%
import math
from tensorflow.keras.callbacks import Callback
from tensorflow.keras import backend as K


class CosineAnnealingScheduler(Callback):
    """Cosine annealing scheduler.
    """

    def __init__(self, T_max, eta_max, eta_min=0, verbose=0):
        super(CosineAnnealingScheduler, self).__init__()
        self.T_max = T_max
        self.eta_max = eta_max
        self.eta_min = eta_min
        self.verbose = verbose

    def on_epoch_begin(self, epoch, logs=None):
        if not hasattr(self.model.optimizer, 'lr'):
            raise ValueError('Optimizer must have a "lr" attribute.')
        lr = self.eta_min + (self.eta_max - self.eta_min) * (1 + math.cos(math.pi * epoch / self.T_max)) / 2
        K.set_value(self.model.optimizer.lr, lr)
        if self.verbose > 0:
            print('\nEpoch %05d: CosineAnnealingScheduler setting learning '
                  'rate to %s.' % (epoch + 1, lr))

    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        logs['lr'] = K.get_value(self.model.optimizer.lr)

# %%
epochs = 15
ca_shed = CosineAnnealingScheduler(T_max=epochs, eta_max=initial_learningrate, eta_min=1e-6,verbose=1)

history=model.fit_generator(aux_data_gen(train_generator),
                    validation_data=aux_data_gen(valid_generator),
                    epochs=epochs,
                    steps_per_epoch=train_m//batch_size+1,
                    validation_steps = valid_m//batch_size+1,
                    callbacks=[ca_shed])

history.history['weighted_recall']= 0.5*np.array(history.history['root_recall'])+0.25*np.array(history.history['consonant_recall'])+0.25*np.array(history.history['vowel_recall'])
history.history['val_weighted_recall']= 0.5*np.array(history.history['val_root_recall'])+0.25*np.array(history.history['val_consonant_recall'])+0.25*np.array(history.history['val_vowel_recall'])
# Out:
# WARNING:tensorflow:From <ipython-input-49-4d74d3959c8f>:10: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Train for 1413 steps, validate for 157 steps
#
# Epoch 00001: CosineAnnealingScheduler setting learning rate to 0.001.
# Epoch 1/15
# 1413/1413 [==============================] - 880s 622ms/step - loss: 8.1990 - root_loss: 3.2002 - vowel_loss: 0.9995 - consonant_loss: 0.7991 - root_recall: 0.2155 - vowel_recall: 0.5967 - consonant_recall: 0.6920 - val_loss: 7.0469 - val_root_loss: 2.6730 - val_vowel_loss: 1.1648 - val_consonant_loss: 0.5361 - val_root_recall: 0.3702 - val_vowel_recall: 0.7004 - val_consonant_recall: 0.8253
#
# Epoch 00002: CosineAnnealingScheduler setting learning rate to 0.000989084726566536.
# Epoch 2/15
# 1413/1413 [==============================] - 847s 600ms/step - loss: 1.7594 - root_loss: 0.6709 - vowel_loss: 0.2192 - consonant_loss: 0.1985 - root_recall: 0.7684 - vowel_recall: 0.9278 - consonant_recall: 0.9354 - val_loss: 4.2817 - val_root_loss: 1.7739 - val_vowel_loss: 0.3129 - val_consonant_loss: 0.4211 - val_root_recall: 0.5215 - val_vowel_recall: 0.9020 - val_consonant_recall: 0.8697
#
# Epoch 00003: CosineAnnealingScheduler setting learning rate to 0.0009568159560924792.
# Epoch 3/15
# 1413/1413 [==============================] - 850s 601ms/step - loss: 1.1476 - root_loss: 0.4324 - vowel_loss: 0.1448 - consonant_loss: 0.1380 - root_recall: 0.8572 - vowel_recall: 0.9562 - consonant_recall: 0.9573 - val_loss: 1.8291 - val_root_loss: 0.7088 - val_vowel_loss: 0.2012 - val_consonant_loss: 0.2104 - val_root_recall: 0.7963 - val_vowel_recall: 0.9415 - val_consonant_recall: 0.9366
#
# Epoch 00004: CosineAnnealingScheduler setting learning rate to 0.0009046039886902864.
# Epoch 4/15
# 1413/1413 [==============================] - 853s 603ms/step - loss: 0.8955 - root_loss: 0.3356 - vowel_loss: 0.1143 - consonant_loss: 0.1100 - root_recall: 0.8903 - vowel_recall: 0.9670 - consonant_recall: 0.9667 - val_loss: 1.1848 - val_root_loss: 0.4719 - val_vowel_loss: 0.1284 - val_consonant_loss: 0.1126 - val_root_recall: 0.8557 - val_vowel_recall: 0.9666 - val_consonant_recall: 0.9671
#
# Epoch 00005: CosineAnnealingScheduler setting learning rate to 0.0008347307378762498.
# Epoch 5/15
# 1413/1413 [==============================] - 851s 602ms/step - loss: 0.7326 - root_loss: 0.2721 - vowel_loss: 0.0952 - consonant_loss: 0.0932 - root_recall: 0.9116 - vowel_recall: 0.9733 - consonant_recall: 0.9728 - val_loss: 0.8464 - val_root_loss: 0.3236 - val_vowel_loss: 0.1080 - val_consonant_loss: 0.0912 - val_root_recall: 0.9031 - val_vowel_recall: 0.9731 - val_consonant_recall: 0.9737
#
# Epoch 00006: CosineAnnealingScheduler setting learning rate to 0.0007502500000000002.
# Epoch 6/15
# 1413/1413 [==============================] - 845s 598ms/step - loss: 0.6085 - root_loss: 0.2253 - vowel_loss: 0.0809 - consonant_loss: 0.0769 - root_recall: 0.9273 - vowel_recall: 0.9778 - consonant_recall: 0.9770 - val_loss: 0.8800 - val_root_loss: 0.3175 - val_vowel_loss: 0.1412 - val_consonant_loss: 0.1038 - val_root_recall: 0.9036 - val_vowel_recall: 0.9634 - val_consonant_recall: 0.9699
#
# Epoch 00007: CosineAnnealingScheduler setting learning rate to 0.0006548539886902864.
# Epoch 7/15
# 1413/1413 [==============================] - 849s 601ms/step - loss: 0.5049 - root_loss: 0.1844 - vowel_loss: 0.0681 - consonant_loss: 0.0680 - root_recall: 0.9401 - vowel_recall: 0.9812 - consonant_recall: 0.9804 - val_loss: 0.7419 - val_root_loss: 0.2855 - val_vowel_loss: 0.0920 - val_consonant_loss: 0.0788 - val_root_recall: 0.9159 - val_vowel_recall: 0.9775 - val_consonant_recall: 0.9771
#
# Epoch 00008: CosineAnnealingScheduler setting learning rate to 0.000552711967402193.
# Epoch 8/15
# 1413/1413 [==============================] - 846s 599ms/step - loss: 0.4138 - root_loss: 0.1502 - vowel_loss: 0.0563 - consonant_loss: 0.0570 - root_recall: 0.9504 - vowel_recall: 0.9847 - consonant_recall: 0.9834 - val_loss: 0.7467 - val_root_loss: 0.2893 - val_vowel_loss: 0.0840 - val_consonant_loss: 0.0841 - val_root_recall: 0.9246 - val_vowel_recall: 0.9800 - val_consonant_recall: 0.9782
#
# Epoch 00009: CosineAnnealingScheduler setting learning rate to 0.00044828803259780724.
# Epoch 9/15
# 1413/1413 [==============================] - 848s 600ms/step - loss: 0.3301 - root_loss: 0.1178 - vowel_loss: 0.0466 - consonant_loss: 0.0478 - root_recall: 0.9607 - vowel_recall: 0.9874 - consonant_recall: 0.9864 - val_loss: 0.5961 - val_root_loss: 0.2264 - val_vowel_loss: 0.0782 - val_consonant_loss: 0.0652 - val_root_recall: 0.9359 - val_vowel_recall: 0.9814 - val_consonant_recall: 0.9824
#
# Epoch 00010: CosineAnnealingScheduler setting learning rate to 0.0003461460113097139.
# Epoch 10/15
# 1413/1413 [==============================] - 848s 600ms/step - loss: 0.2579 - root_loss: 0.0904 - vowel_loss: 0.0385 - consonant_loss: 0.0387 - root_recall: 0.9700 - vowel_recall: 0.9894 - consonant_recall: 0.9888 - val_loss: 0.5881 - val_root_loss: 0.2199 - val_vowel_loss: 0.0811 - val_consonant_loss: 0.0673 - val_root_recall: 0.9431 - val_vowel_recall: 0.9831 - val_consonant_recall: 0.9828
#
# Epoch 00011: CosineAnnealingScheduler setting learning rate to 0.00025075000000000016.
# Epoch 11/15
# 1413/1413 [==============================] - 850s 602ms/step - loss: 0.1953 - root_loss: 0.0664 - vowel_loss: 0.0311 - consonant_loss: 0.0315 - root_recall: 0.9777 - vowel_recall: 0.9917 - consonant_recall: 0.9908 - val_loss: 0.5863 - val_root_loss: 0.2160 - val_vowel_loss: 0.0747 - val_consonant_loss: 0.0796 - val_root_recall: 0.9459 - val_vowel_recall: 0.9845 - val_consonant_recall: 0.9828
#
# Epoch 00012: CosineAnnealingScheduler setting learning rate to 0.0001662692621237505.
# Epoch 12/15
# 1413/1413 [==============================] - 854s 605ms/step - loss: 0.1434 - root_loss: 0.0467 - vowel_loss: 0.0246 - consonant_loss: 0.0253 - root_recall: 0.9842 - vowel_recall: 0.9931 - consonant_recall: 0.9927 - val_loss: 0.5895 - val_root_loss: 0.2240 - val_vowel_loss: 0.0729 - val_consonant_loss: 0.0688 - val_root_recall: 0.9491 - val_vowel_recall: 0.9858 - val_consonant_recall: 0.9855
#
# Epoch 00013: CosineAnnealingScheduler setting learning rate to 9.639601130971382e-05.
# Epoch 13/15
# 1413/1413 [==============================] - 853s 604ms/step - loss: 0.1084 - root_loss: 0.0348 - vowel_loss: 0.0191 - consonant_loss: 0.0197 - root_recall: 0.9881 - vowel_recall: 0.9948 - consonant_recall: 0.9943 - val_loss: 0.5926 - val_root_loss: 0.2241 - val_vowel_loss: 0.0729 - val_consonant_loss: 0.0714 - val_root_recall: 0.9495 - val_vowel_recall: 0.9857 - val_consonant_recall: 0.9852
#
# Epoch 00014: CosineAnnealingScheduler setting learning rate to 4.418404390752081e-05.
# Epoch 14/15
# 1413/1413 [==============================] - 852s 603ms/step - loss: 0.0856 - root_loss: 0.0268 - vowel_loss: 0.0158 - consonant_loss: 0.0163 - root_recall: 0.9910 - vowel_recall: 0.9956 - consonant_recall: 0.9951 - val_loss: 0.5977 - val_root_loss: 0.2261 - val_vowel_loss: 0.0730 - val_consonant_loss: 0.0725 - val_root_recall: 0.9504 - val_vowel_recall: 0.9865 - val_consonant_recall: 0.9859
#
# Epoch 00015: CosineAnnealingScheduler setting learning rate to 1.191527343346406e-05.
# Epoch 15/15
# 1413/1413 [==============================] - 853s 604ms/step - loss: 0.0719 - root_loss: 0.0219 - vowel_loss: 0.0138 - consonant_loss: 0.0143 - root_recall: 0.9925 - vowel_recall: 0.9961 - consonant_recall: 0.9959 - val_loss: 0.5612 - val_root_loss: 0.2100 - val_vowel_loss: 0.0710 - val_consonant_loss: 0.0702 - val_root_recall: 0.9530 - val_vowel_recall: 0.9864 - val_consonant_recall: 0.9858

# %%
model.save_weights('/content/drive/My Drive/kaggle/bengali/output/w_inceptionv3_eps15_sr01_rmsprop.h5')
model.save('/content/drive/My Drive/kaggle/bengali/output/m_inceptionv3_eps15_sr01_rmsprop.h5')
pd.DataFrame(history.history).to_csv('/content/drive/My Drive/kaggle/bengali/output/h_inceptionv3.csv', index=False)

# %%
model.optimizer.get_config()
# Out:
# {'centered': False,
#  'decay': 0.0,
#  'epsilon': 1e-07,
#  'learning_rate': 1.1915274e-05,
#  'momentum': 0.0,
#  'name': 'RMSprop',
#  'rho': 0.9}

# %%
from matplotlib import pyplot as plt

# %%
# %matplotlib inline

plt.style.use('ggplot')
plt.figure()
plt.plot(np.arange(0, epochs), history.history['loss'], label='loss')
plt.plot(np.arange(0, epochs), history.history['val_loss'], label='val_loss')
plt.plot(np.arange(0, epochs), history.history['val_root_loss'], label='val_root_loss')
plt.plot(np.arange(0, epochs), history.history['val_vowel_loss'], label='val_vowel_loss')
plt.plot(np.arange(0, epochs), history.history['val_consonant_loss'], label='val_consonant_loss')

    
plt.title('loss')
plt.xlabel('Epoch #')
plt.ylabel('Loss')
plt.legend(loc='upper right')
plt.show()

# %%
plt.style.use('ggplot')
plt.figure()
plt.plot(np.arange(0, epochs), history.history['weighted_recall'], label='weighted_recall')
plt.plot(np.arange(0, epochs), history.history['val_root_recall'], label='val_root_recall')
plt.plot(np.arange(0, epochs), history.history['val_vowel_recall'], label='val_vowel_recall')
plt.plot(np.arange(0, epochs), history.history['val_consonant_recall'], label='val_consonant_recall')

    
plt.title('recall')
plt.xlabel('Epoch #')
plt.ylabel('Loss')
plt.legend(loc='upper right')
plt.show()

# %%
plt.style.use('ggplot')
plt.figure()
plt.plot(np.arange(0, epochs), history.history['lr'], label='lr')

    
plt.title('lr')
plt.xlabel('Epoch #')
plt.ylabel('Loss')
plt.legend(loc='upper right')
plt.show()

# %%
plt.style.use('ggplot')
plt.figure()
plt.plot(np.arange(0, epochs), history.history['weighted_recall'], label='w_recall')
plt.plot(np.arange(0, epochs), history.history['val_weighted_recall'], label='val_w_recall')
    
plt.title('recall')
plt.xlabel('Epoch #')
plt.ylabel('Loss')
plt.legend(loc='upper right')
plt.show()
