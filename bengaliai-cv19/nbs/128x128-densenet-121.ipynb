# %%
# !ls
# Out:
# sample_data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !mkdir train

# %%
# !mkdir train/128

# %%
# !cp '/content/drive/My Drive/kaggle/bengali/input/grapheme-imgs-128x128.zip' train

# %%
# !cp '/content/drive/My Drive/kaggle/bengali/input/train.csv' train

# %%
# !cp '/content/drive/My Drive/kaggle/bengali/input/DenseNet-BC-121-32-no-top.h5' train

# %%
# !unzip train/grapheme-imgs-128x128.zip  -d train/128/

# %%
# !ls train
# Out:
# 128  grapheme-imgs-128x128.zip	train.csv

# %%
# %tensorflow_version 2.x

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import cv2

import tensorflow as tf
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import LeakyReLU
from keras.layers.normalization import BatchNormalization
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.callbacks import ReduceLROnPlateau,LambdaCallback
from tensorflow.keras import layers


# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
#for dirname, _, filenames in os.walk('/kaggle/input'):
#    for filename in filenames:
#        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.

# %%
os.chdir('/content/')

# %%
dataset_np = pd.read_csv('./train/train.csv').to_numpy()
train_dir='./train/128'

# %%
dataset_np[:,0]+='.png'
dataset_m = dataset_np.shape[0]
split_rate = 0.25
valid_m = int(dataset_m*split_rate)
train_m = int(dataset_m-valid_m)
indicies=np.arange(dataset_m)
np.random.shuffle(indicies)
random_train_inds = indicies[0:train_m]
random_valid_inds = indicies[train_m:train_m+valid_m]
train_np = dataset_np[random_train_inds]
valid_np = dataset_np[random_valid_inds]
train_df = pd.DataFrame(train_np)
valid_df = pd.DataFrame(valid_np)
train_df.rename(columns={0:'filename',1:'root_class',2:'vowel_class',3:'cons_class', 4:'grapheme'}, inplace=True)
valid_df.rename(columns={0:'filename',1:'root_class',2:'vowel_class',3:'cons_class', 4:'grapheme'}, inplace=True)

# %%
def build_model(densenet):
    x_in = layers.Input(shape=(128, 128, 3))
    x = densenet(x_in)
    
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.5)(x)
    x = layers.Dense(256)(x)
    x = layers.LeakyReLU(alpha=0.1)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.5)(x)
    
    out_root = tf.keras.layers.Dense(168, activation='softmax', name='root')(x)
    out_vowel = tf.keras.layers.Dense(11, activation='softmax', name='vowel')(x)
    out_consonant = tf.keras.layers.Dense(7, activation='softmax', name='consonant')(x)
    
    model = tf.keras.Model(inputs=x_in, outputs=[out_root, out_vowel, out_consonant])
    
    return model

# %%
densenet_weights = './train/DenseNet-BC-121-32-no-top.h5'
densenet = DenseNet121(include_top=False, weights=densenet_weights, input_shape=(128, 128, 3))

# %%
model = build_model(densenet)

loss_dict={'root': 'categorical_crossentropy',
           'vowel':    'categorical_crossentropy',
           'consonant':'categorical_crossentropy'}
metrics_dict={ 'root':     [tf.keras.metrics.Recall(name='recall')],
               'vowel':    [tf.keras.metrics.Recall(name='recall')],
               'consonant':[tf.keras.metrics.Recall(name='recall')]}

initial_learningrate=1e-3
model.compile(optimizer=RMSprop(lr=initial_learningrate), loss=loss_dict, loss_weights=[2.0,1.0,1.0], 
                  metrics=metrics_dict)

# %%
tf.keras.utils.plot_model(model, to_file='model.png', show_shapes=True)

# %%
train_datagen = ImageDataGenerator(rotation_range = 10,
                                   shear_range = 0.1)

valid_datagen = ImageDataGenerator()

# %%
columns=["root_class","vowel_class", "cons_class"]
batch_size = 128
train_generator = train_datagen.flow_from_dataframe(
        dataframe=train_df,
        directory=train_dir,
        x_col="filename",
        y_col=columns,
        target_size=(128, 128),
        batch_size=batch_size,
        class_mode="multi_output",
        colormode="greyscale")

valid_generator = valid_datagen.flow_from_dataframe(
        dataframe=valid_df,
        directory=train_dir,
        x_col="filename",
        y_col=columns,
        target_size=(128, 128),
        batch_size=batch_size,
        class_mode="multi_output",
        colormode="greyscale")
# Out:
# Found 150630 validated image filenames.
# Found 50210 validated image filenames.

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 11865037929204160941, name: "/device:XLA_CPU:0"
#  device_type: "XLA_CPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 7158314118165850044
#  physical_device_desc: "device: XLA_CPU device", name: "/device:XLA_GPU:0"
#  device_type: "XLA_GPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 14873800135322263381
#  physical_device_desc: "device: XLA_GPU device", name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 15956161332
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 13025970531958749864
#  physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0"]

# %%
def split_into_3_outputs(y_batch):
    
    y1=tf.keras.utils.to_categorical(y_batch[0],168)
    y2=tf.keras.utils.to_categorical(y_batch[1],11)
    y3=tf.keras.utils.to_categorical(y_batch[2],7)
    
    return y1,y2,y3

# %%
def aux_data_gen(generator):
    stats = (0.0692, 0.2051)
    while True:
        batch = next(generator)
        batch_x = (batch[0].astype(np.float32)/255.0 - stats[0])/stats[1]
        yield batch_x, split_into_3_outputs(batch[1])

# %%
import math
from tensorflow.keras.callbacks import Callback
from tensorflow.keras import backend as K


class CosineAnnealingScheduler(Callback):
    """Cosine annealing scheduler.
    """

    def __init__(self, T_max, eta_max, eta_min=0, verbose=0):
        super(CosineAnnealingScheduler, self).__init__()
        self.T_max = T_max
        self.eta_max = eta_max
        self.eta_min = eta_min
        self.verbose = verbose

    def on_epoch_begin(self, epoch, logs=None):
        if not hasattr(self.model.optimizer, 'lr'):
            raise ValueError('Optimizer must have a "lr" attribute.')
        lr = self.eta_min + (self.eta_max - self.eta_min) * (1 + math.cos(math.pi * epoch / self.T_max)) / 2
        K.set_value(self.model.optimizer.lr, lr)
        if self.verbose > 0:
            print('\nEpoch %05d: CosineAnnealingScheduler setting learning '
                  'rate to %s.' % (epoch + 1, lr))

    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        logs['lr'] = K.get_value(self.model.optimizer.lr)

# %%
epochs = 25

wr_history=[]

wr_callback = LambdaCallback(on_epoch_end=lambda batch, logs: wr_history.append(0.5*logs['root_recall']+
                                                                                0.25*logs['consonant_recall']+
                                                                                0.25*logs['vowel_recall']))
ca_shed = CosineAnnealingScheduler(T_max=epochs, eta_max=initial_learningrate, eta_min=1e-6,verbose=1)

learning_rate_reduction = ReduceLROnPlateau(monitor='loss', 
                                            patience=2, 
                                            verbose=1, 
                                            factor=0.2, 
                                            min_lr=0.00001)

history=model.fit_generator(aux_data_gen(train_generator),
                    validation_data=aux_data_gen(valid_generator),
                    epochs=epochs,
                    steps_per_epoch=train_m//batch_size+1,
                    validation_steps = valid_m//batch_size+1,
                    callbacks=[wr_callback,ca_shed])

history.history['weighted_recall']=wr_history
# Out:
# Epoch 00001: CosineAnnealingScheduler setting learning rate to 0.001.
# Epoch 1/25
# 1176/1177 [============================>.] - ETA: 0s - loss: 3.6704 - root_loss: 1.4279 - vowel_loss: 0.4451 - consonant_loss: 0.3696 - root_recall: 0.5598 - vowel_recall: 0.8391 - consonant_recall: 0.8782Epoch 1/25
# 1177/1177 [==============================] - 903s 767ms/step - loss: 3.6687 - root_loss: 1.4272 - vowel_loss: 0.4449 - consonant_loss: 0.3694 - root_recall: 0.5599 - vowel_recall: 0.8392 - consonant_recall: 0.8783 - val_loss: 1.6275 - val_root_loss: 0.5890 - val_vowel_loss: 0.2469 - val_consonant_loss: 0.2026 - val_root_recall: 0.8216 - val_vowel_recall: 0.9349 - val_consonant_recall: 0.9447
#
# Epoch 00002: CosineAnnealingScheduler setting learning rate to 0.0009960612933065818.
# Epoch 2/25
# 1176/1177 [============================>.] - ETA: 0s - loss: 1.2490 - root_loss: 0.4599 - vowel_loss: 0.1729 - consonant_loss: 0.1563 - root_recall: 0.8447 - vowel_recall: 0.9498 - consonant_recall: 0.9547Epoch 1/25
# 1177/1177 [==============================] - 830s 705ms/step - loss: 1.2487 - root_loss: 0.4597 - vowel_loss: 0.1729 - consonant_loss: 0.1563 - root_recall: 0.8447 - vowel_recall: 0.9498 - consonant_recall: 0.9547 - val_loss: 1.1090 - val_root_loss: 0.4417 - val_vowel_loss: 0.1206 - val_consonant_loss: 0.1051 - val_root_recall: 0.8670 - val_vowel_recall: 0.9666 - val_consonant_recall: 0.9685
#
# Epoch 00003: CosineAnnealingScheduler setting learning rate to 0.0009843072889837512.
# Epoch 3/25
# 1176/1177 [============================>.] - ETA: 0s - loss: 0.9725 - root_loss: 0.3567 - vowel_loss: 0.1334 - consonant_loss: 0.1256 - root_recall: 0.8851 - vowel_recall: 0.9631 - consonant_recall: 0.9643Epoch 1/25
# 1177/1177 [==============================] - 829s 704ms/step - loss: 0.9723 - root_loss: 0.3567 - vowel_loss: 0.1334 - consonant_loss: 0.1256 - root_recall: 0.8851 - vowel_recall: 0.9631 - consonant_recall: 0.9643 - val_loss: 0.8826 - val_root_loss: 0.3290 - val_vowel_loss: 0.1002 - val_consonant_loss: 0.1244 - val_root_recall: 0.9010 - val_vowel_recall: 0.9764 - val_consonant_recall: 0.9643
#
# Epoch 00004: CosineAnnealingScheduler setting learning rate to 0.0009649233547011816.
# Epoch 4/25
# 1176/1177 [============================>.] - ETA: 0s - loss: 0.8261 - root_loss: 0.3023 - vowel_loss: 0.1140 - consonant_loss: 0.1075 - root_recall: 0.9044 - vowel_recall: 0.9695 - consonant_recall: 0.9704Epoch 1/25
# 1177/1177 [==============================] - 828s 703ms/step - loss: 0.8260 - root_loss: 0.3023 - vowel_loss: 0.1140 - consonant_loss: 0.1074 - root_recall: 0.9044 - vowel_recall: 0.9695 - consonant_recall: 0.9704 - val_loss: 0.8930 - val_root_loss: 0.3059 - val_vowel_loss: 0.1596 - val_consonant_loss: 0.1217 - val_root_recall: 0.9082 - val_vowel_recall: 0.9613 - val_consonant_recall: 0.9687
#
# Epoch 00005: CosineAnnealingScheduler setting learning rate to 0.0009382151866819099.
# Epoch 5/25
# 1176/1177 [============================>.] - ETA: 0s - loss: 0.7183 - root_loss: 0.2630 - vowel_loss: 0.0984 - consonant_loss: 0.0938 - root_recall: 0.9178 - vowel_recall: 0.9742 - consonant_recall: 0.9745Epoch 1/25
# 1177/1177 [==============================] - 825s 701ms/step - loss: 0.7185 - root_loss: 0.2632 - vowel_loss: 0.0984 - consonant_loss: 0.0938 - root_recall: 0.9179 - vowel_recall: 0.9742 - consonant_recall: 0.9745 - val_loss: 0.7630 - val_root_loss: 0.2954 - val_vowel_loss: 0.0912 - val_consonant_loss: 0.0810 - val_root_recall: 0.9214 - val_vowel_recall: 0.9791 - val_consonant_recall: 0.9797
#
# Epoch 00006: CosineAnnealingScheduler setting learning rate to 0.0009046039886902864.
# Epoch 6/25
# 1176/1177 [============================>.] - ETA: 0s - loss: 0.6331 - root_loss: 0.2314 - vowel_loss: 0.0875 - consonant_loss: 0.0827 - root_recall: 0.9288 - vowel_recall: 0.9776 - consonant_recall: 0.9775Epoch 1/25
# 1177/1177 [==============================] - 821s 698ms/step - loss: 0.6332 - root_loss: 0.2315 - vowel_loss: 0.0875 - consonant_loss: 0.0827 - root_recall: 0.9288 - vowel_recall: 0.9776 - consonant_recall: 0.9775 - val_loss: 0.7606 - val_root_loss: 0.2867 - val_vowel_loss: 0.1075 - val_consonant_loss: 0.0797 - val_root_recall: 0.9193 - val_vowel_recall: 0.9750 - val_consonant_recall: 0.9791
#
# Epoch 00007: CosineAnnealingScheduler setting learning rate to 0.0008646198293969952.
# Epoch 7/25
# 1176/1177 [============================>.] - ETA: 0s - loss: 0.5702 - root_loss: 0.2073 - vowel_loss: 0.0799 - consonant_loss: 0.0758 - root_recall: 0.9367 - vowel_recall: 0.9805 - consonant_recall: 0.9797Epoch 1/25
# 1177/1177 [==============================] - 826s 702ms/step - loss: 0.5703 - root_loss: 0.2073 - vowel_loss: 0.0799 - consonant_loss: 0.0758 - root_recall: 0.9367 - vowel_recall: 0.9805 - consonant_recall: 0.9796 - val_loss: 0.7322 - val_root_loss: 0.2783 - val_vowel_loss: 0.0881 - val_consonant_loss: 0.0874 - val_root_recall: 0.9282 - val_vowel_recall: 0.9808 - val_consonant_recall: 0.9773
#
# Epoch 00008: CosineAnnealingScheduler setting learning rate to 0.0008188932828794706.
# Epoch 8/25
# 1176/1177 [============================>.] - ETA: 0s - loss: 0.5056 - root_loss: 0.1834 - vowel_loss: 0.0704 - consonant_loss: 0.0685 - root_recall: 0.9445 - vowel_recall: 0.9827 - consonant_recall: 0.9819Epoch 1/25
# 1177/1177 [==============================] - 824s 700ms/step - loss: 0.5056 - root_loss: 0.1834 - vowel_loss: 0.0704 - consonant_loss: 0.0685 - root_recall: 0.9445 - vowel_recall: 0.9827 - consonant_recall: 0.9819 - val_loss: 0.6384 - val_root_loss: 0.2428 - val_vowel_loss: 0.0827 - val_consonant_loss: 0.0701 - val_root_recall: 0.9360 - val_vowel_recall: 0.9819 - val_consonant_recall: 0.9814
#
# Epoch 00009: CosineAnnealingScheduler setting learning rate to 0.0007681454840920089.
# Epoch 9/25
# 1176/1177 [============================>.] - ETA: 0s - loss: 0.4478 - root_loss: 0.1621 - vowel_loss: 0.0633 - consonant_loss: 0.0604 - root_recall: 0.9512 - vowel_recall: 0.9847 - consonant_recall: 0.9842Epoch 1/25
# 1177/1177 [==============================] - 823s 699ms/step - loss: 0.4480 - root_loss: 0.1621 - vowel_loss: 0.0634 - consonant_loss: 0.0603 - root_recall: 0.9512 - vowel_recall: 0.9847 - consonant_recall: 0.9842 - val_loss: 0.6455 - val_root_loss: 0.2425 - val_vowel_loss: 0.0822 - val_consonant_loss: 0.0783 - val_root_recall: 0.9376 - val_vowel_recall: 0.9827 - val_consonant_recall: 0.9819
#
# Epoch 00010: CosineAnnealingScheduler setting learning rate to 0.0007131767561367538.
# Epoch 10/25
# 1176/1177 [============================>.] - ETA: 0s - loss: 0.3986 - root_loss: 0.1432 - vowel_loss: 0.0580 - consonant_loss: 0.0541 - root_recall: 0.9566 - vowel_recall: 0.9860 - consonant_recall: 0.9860Epoch 1/25
# 1177/1177 [==============================] - 823s 699ms/step - loss: 0.3987 - root_loss: 0.1433 - vowel_loss: 0.0580 - consonant_loss: 0.0541 - root_recall: 0.9566 - vowel_recall: 0.9860 - consonant_recall: 0.9861 - val_loss: 0.7006 - val_root_loss: 0.2653 - val_vowel_loss: 0.0933 - val_consonant_loss: 0.0768 - val_root_recall: 0.9385 - val_vowel_recall: 0.9827 - val_consonant_recall: 0.9825
#
# Epoch 00011: CosineAnnealingScheduler setting learning rate to 0.0006548539886902864.
# Epoch 11/25
# 1176/1177 [============================>.] - ETA: 0s - loss: 0.3507 - root_loss: 0.1254 - vowel_loss: 0.0516 - consonant_loss: 0.0483 - root_recall: 0.9621 - vowel_recall: 0.9877 - consonant_recall: 0.9878Epoch 1/25
# 1177/1177 [==============================] - 820s 697ms/step - loss: 0.3509 - root_loss: 0.1255 - vowel_loss: 0.0516 - consonant_loss: 0.0482 - root_recall: 0.9621 - vowel_recall: 0.9877 - consonant_recall: 0.9878 - val_loss: 0.5921 - val_root_loss: 0.2278 - val_vowel_loss: 0.0747 - val_consonant_loss: 0.0618 - val_root_recall: 0.9421 - val_vowel_recall: 0.9836 - val_consonant_recall: 0.9841
#
# Epoch 00012: CosineAnnealingScheduler setting learning rate to 0.0005940969666355697.
# Epoch 12/25
# 1176/1177 [============================>.] - ETA: 0s - loss: 0.3023 - root_loss: 0.1054 - vowel_loss: 0.0473 - consonant_loss: 0.0442 - root_recall: 0.9683 - vowel_recall: 0.9887 - consonant_recall: 0.9890Epoch 1/25
# 1177/1177 [==============================] - 822s 699ms/step - loss: 0.3022 - root_loss: 0.1054 - vowel_loss: 0.0472 - consonant_loss: 0.0443 - root_recall: 0.9683 - vowel_recall: 0.9887 - consonant_recall: 0.9890 - val_loss: 0.5999 - val_root_loss: 0.2286 - val_vowel_loss: 0.0761 - val_consonant_loss: 0.0666 - val_root_recall: 0.9460 - val_vowel_recall: 0.9848 - val_consonant_recall: 0.9846
#
# Epoch 00013: CosineAnnealingScheduler setting learning rate to 0.0005318638645048922.
# Epoch 13/25
# 1176/1177 [============================>.] - ETA: 0s - loss: 0.2654 - root_loss: 0.0918 - vowel_loss: 0.0423 - consonant_loss: 0.0395 - root_recall: 0.9725 - vowel_recall: 0.9901 - consonant_recall: 0.9903Epoch 1/25
# 1177/1177 [==============================] - 826s 701ms/step - loss: 0.2654 - root_loss: 0.0918 - vowel_loss: 0.0422 - consonant_loss: 0.0395 - root_recall: 0.9725 - vowel_recall: 0.9901 - consonant_recall: 0.9903 - val_loss: 0.5940 - val_root_loss: 0.2247 - val_vowel_loss: 0.0743 - val_consonant_loss: 0.0702 - val_root_recall: 0.9476 - val_vowel_recall: 0.9857 - val_consonant_recall: 0.9847
#
# Epoch 00014: CosineAnnealingScheduler setting learning rate to 0.00046913613549510807.
# Epoch 14/25
# 1176/1177 [============================>.] - ETA: 0s - loss: 0.2265 - root_loss: 0.0770 - vowel_loss: 0.0379 - consonant_loss: 0.0346 - root_recall: 0.9766 - vowel_recall: 0.9913 - consonant_recall: 0.9914Epoch 1/25
# 1177/1177 [==============================] - 824s 700ms/step - loss: 0.2267 - root_loss: 0.0770 - vowel_loss: 0.0380 - consonant_loss: 0.0347 - root_recall: 0.9765 - vowel_recall: 0.9913 - consonant_recall: 0.9914 - val_loss: 0.6725 - val_root_loss: 0.2522 - val_vowel_loss: 0.0966 - val_consonant_loss: 0.0714 - val_root_recall: 0.9502 - val_vowel_recall: 0.9846 - val_consonant_recall: 0.9855
#
# Epoch 00015: CosineAnnealingScheduler setting learning rate to 0.00040690303336443065.
# Epoch 15/25
# 1176/1177 [============================>.] - ETA: 0s - loss: 0.1850 - root_loss: 0.0620 - vowel_loss: 0.0311 - consonant_loss: 0.0298 - root_recall: 0.9808 - vowel_recall: 0.9926 - consonant_recall: 0.9927Epoch 1/25
# 1177/1177 [==============================] - 822s 698ms/step - loss: 0.1849 - root_loss: 0.0620 - vowel_loss: 0.0311 - consonant_loss: 0.0298 - root_recall: 0.9808 - vowel_recall: 0.9926 - consonant_recall: 0.9927 - val_loss: 0.6018 - val_root_loss: 0.2273 - val_vowel_loss: 0.0797 - val_consonant_loss: 0.0674 - val_root_recall: 0.9529 - val_vowel_recall: 0.9855 - val_consonant_recall: 0.9857
#
# Epoch 00016: CosineAnnealingScheduler setting learning rate to 0.000346146011309714.
# Epoch 16/25
# 1176/1177 [============================>.] - ETA: 0s - loss: 0.1513 - root_loss: 0.0492 - vowel_loss: 0.0278 - consonant_loss: 0.0250 - root_recall: 0.9843 - vowel_recall: 0.9934 - consonant_recall: 0.9939Epoch 1/25
# 1177/1177 [==============================] - 823s 699ms/step - loss: 0.1515 - root_loss: 0.0493 - vowel_loss: 0.0279 - consonant_loss: 0.0250 - root_recall: 0.9843 - vowel_recall: 0.9934 - consonant_recall: 0.9939 - val_loss: 0.6439 - val_root_loss: 0.2471 - val_vowel_loss: 0.0762 - val_consonant_loss: 0.0735 - val_root_recall: 0.9512 - val_vowel_recall: 0.9866 - val_consonant_recall: 0.9853
#
# Epoch 00017: CosineAnnealingScheduler setting learning rate to 0.00028782324386324626.
# Epoch 17/25
# 1176/1177 [============================>.] - ETA: 0s - loss: 0.1256 - root_loss: 0.0395 - vowel_loss: 0.0242 - consonant_loss: 0.0224 - root_recall: 0.9875 - vowel_recall: 0.9944 - consonant_recall: 0.9945Epoch 1/25
# 1177/1177 [==============================] - 821s 698ms/step - loss: 0.1258 - root_loss: 0.0396 - vowel_loss: 0.0242 - consonant_loss: 0.0224 - root_recall: 0.9875 - vowel_recall: 0.9944 - consonant_recall: 0.9945 - val_loss: 0.7350 - val_root_loss: 0.2785 - val_vowel_loss: 0.0952 - val_consonant_loss: 0.0828 - val_root_recall: 0.9534 - val_vowel_recall: 0.9848 - val_consonant_recall: 0.9858
#
# Epoch 00018: CosineAnnealingScheduler setting learning rate to 0.00023285451590799108.
# Epoch 18/25
# 1176/1177 [============================>.] - ETA: 0s - loss: 0.0990 - root_loss: 0.0293 - vowel_loss: 0.0213 - consonant_loss: 0.0191 - root_recall: 0.9906 - vowel_recall: 0.9950 - consonant_recall: 0.9954Epoch 1/25
# 1177/1177 [==============================] - 820s 697ms/step - loss: 0.0989 - root_loss: 0.0293 - vowel_loss: 0.0212 - consonant_loss: 0.0191 - root_recall: 0.9906 - vowel_recall: 0.9950 - consonant_recall: 0.9954 - val_loss: 0.7315 - val_root_loss: 0.2776 - val_vowel_loss: 0.0924 - val_consonant_loss: 0.0839 - val_root_recall: 0.9533 - val_vowel_recall: 0.9863 - val_consonant_recall: 0.9861
#
# Epoch 00019: CosineAnnealingScheduler setting learning rate to 0.00018210671712052948.
# Epoch 19/25
# 1176/1177 [============================>.] - ETA: 0s - loss: 0.0763 - root_loss: 0.0218 - vowel_loss: 0.0172 - consonant_loss: 0.0155 - root_recall: 0.9931 - vowel_recall: 0.9959 - consonant_recall: 0.9961Epoch 1/25
# 1177/1177 [==============================] - 822s 698ms/step - loss: 0.0763 - root_loss: 0.0218 - vowel_loss: 0.0172 - consonant_loss: 0.0155 - root_recall: 0.9931 - vowel_recall: 0.9959 - consonant_recall: 0.9961 - val_loss: 0.7070 - val_root_loss: 0.2687 - val_vowel_loss: 0.0869 - val_consonant_loss: 0.0828 - val_root_recall: 0.9571 - val_vowel_recall: 0.9872 - val_consonant_recall: 0.9869
#
# Epoch 00020: CosineAnnealingScheduler setting learning rate to 0.00013638017060300505.
# Epoch 20/25
# 1176/1177 [============================>.] - ETA: 0s - loss: 0.0591 - root_loss: 0.0161 - vowel_loss: 0.0146 - consonant_loss: 0.0124 - root_recall: 0.9950 - vowel_recall: 0.9965 - consonant_recall: 0.9968Epoch 1/25
# 1177/1177 [==============================] - 820s 697ms/step - loss: 0.0592 - root_loss: 0.0161 - vowel_loss: 0.0146 - consonant_loss: 0.0125 - root_recall: 0.9950 - vowel_recall: 0.9965 - consonant_recall: 0.9968 - val_loss: 0.7612 - val_root_loss: 0.2881 - val_vowel_loss: 0.0937 - val_consonant_loss: 0.0912 - val_root_recall: 0.9569 - val_vowel_recall: 0.9877 - val_consonant_recall: 0.9866
#
# Epoch 00021: CosineAnnealingScheduler setting learning rate to 9.639601130971382e-05.
# Epoch 21/25
# 1176/1177 [============================>.] - ETA: 0s - loss: 0.0465 - root_loss: 0.0122 - vowel_loss: 0.0118 - consonant_loss: 0.0102 - root_recall: 0.9961 - vowel_recall: 0.9971 - consonant_recall: 0.9973Epoch 1/25
# 1177/1177 [==============================] - 823s 699ms/step - loss: 0.0465 - root_loss: 0.0122 - vowel_loss: 0.0118 - consonant_loss: 0.0102 - root_recall: 0.9961 - vowel_recall: 0.9971 - consonant_recall: 0.9973 - val_loss: 0.7519 - val_root_loss: 0.2863 - val_vowel_loss: 0.0923 - val_consonant_loss: 0.0869 - val_root_recall: 0.9577 - val_vowel_recall: 0.9875 - val_consonant_recall: 0.9869
#
# Epoch 00022: CosineAnnealingScheduler setting learning rate to 6.278481331809015e-05.
# Epoch 22/25
# 1176/1177 [============================>.] - ETA: 0s - loss: 0.0369 - root_loss: 0.0089 - vowel_loss: 0.0104 - consonant_loss: 0.0087 - root_recall: 0.9971 - vowel_recall: 0.9973 - consonant_recall: 0.9978Epoch 1/25
# 1177/1177 [==============================] - 818s 695ms/step - loss: 0.0369 - root_loss: 0.0089 - vowel_loss: 0.0104 - consonant_loss: 0.0087 - root_recall: 0.9971 - vowel_recall: 0.9973 - consonant_recall: 0.9977 - val_loss: 0.7730 - val_root_loss: 0.2957 - val_vowel_loss: 0.0908 - val_consonant_loss: 0.0908 - val_root_recall: 0.9570 - val_vowel_recall: 0.9876 - val_consonant_recall: 0.9861
#
# Epoch 00023: CosineAnnealingScheduler setting learning rate to 3.6076645298818454e-05.
# Epoch 23/25
# 1176/1177 [============================>.] - ETA: 0s - loss: 0.0296 - root_loss: 0.0070 - vowel_loss: 0.0087 - consonant_loss: 0.0070 - root_recall: 0.9981 - vowel_recall: 0.9978 - consonant_recall: 0.9981Epoch 1/25
# 1177/1177 [==============================] - 820s 696ms/step - loss: 0.0296 - root_loss: 0.0070 - vowel_loss: 0.0087 - consonant_loss: 0.0070 - root_recall: 0.9981 - vowel_recall: 0.9978 - consonant_recall: 0.9981 - val_loss: 0.7425 - val_root_loss: 0.2810 - val_vowel_loss: 0.0927 - val_consonant_loss: 0.0879 - val_root_recall: 0.9590 - val_vowel_recall: 0.9875 - val_consonant_recall: 0.9869
#
# Epoch 00024: CosineAnnealingScheduler setting learning rate to 1.6692711016248837e-05.
# Epoch 24/25
# 1176/1177 [============================>.] - ETA: 0s - loss: 0.0260 - root_loss: 0.0058 - vowel_loss: 0.0080 - consonant_loss: 0.0064 - root_recall: 0.9983 - vowel_recall: 0.9979 - consonant_recall: 0.9982Epoch 1/25
# 1177/1177 [==============================] - 820s 697ms/step - loss: 0.0260 - root_loss: 0.0058 - vowel_loss: 0.0080 - consonant_loss: 0.0064 - root_recall: 0.9983 - vowel_recall: 0.9979 - consonant_recall: 0.9982 - val_loss: 0.7839 - val_root_loss: 0.2984 - val_vowel_loss: 0.0934 - val_consonant_loss: 0.0938 - val_root_recall: 0.9579 - val_vowel_recall: 0.9875 - val_consonant_recall: 0.9861
#
# Epoch 00025: CosineAnnealingScheduler setting learning rate to 4.938706693418357e-06.
# Epoch 25/25
# 1176/1177 [============================>.] - ETA: 0s - loss: 0.0246 - root_loss: 0.0053 - vowel_loss: 0.0080 - consonant_loss: 0.0059 - root_recall: 0.9985 - vowel_recall: 0.9979 - consonant_recall: 0.9983Epoch 1/25
# 1177/1177 [==============================] - 823s 699ms/step - loss: 0.0246 - root_loss: 0.0053 - vowel_loss: 0.0080 - consonant_loss: 0.0059 - root_recall: 0.9985 - vowel_recall: 0.9979 - consonant_recall: 0.9983 - val_loss: 0.7576 - val_root_loss: 0.2881 - val_vowel_loss: 0.0933 - val_consonant_loss: 0.0881 - val_root_recall: 0.9585 - val_vowel_recall: 0.9878 - val_consonant_recall: 0.9868

# %%
model.save_weights('/content/drive/My Drive/kaggle/bengali/input/w_dense_eps25_sr025.h5')
model.save("/content/drive/My Drive/kaggle/bengali/input/m_dense_eps25_sr025.h5")
pd.DataFrame(history.history).to_csv('/content/drive/My Drive/kaggle/bengali/input/h_dense.csv', index=False)

# %%
model.optimizer.get_config()
# Out:
# {'centered': False,
#  'decay': 0.0,
#  'epsilon': 1e-07,
#  'learning_rate': 4.9387068e-06,
#  'momentum': 0.0,
#  'name': 'RMSprop',
#  'rho': 0.9}

# %%
history.history
# Out:
# {'consonant_loss': [0.36939344,
#   0.15634052,
#   0.12559682,
#   0.10739041,
#   0.09378371,
#   0.08268699,
#   0.075783245,
#   0.068459906,
#   0.060330946,
#   0.054146975,
#   0.048246015,
#   0.044261083,
#   0.03950669,
#   0.034710415,
#   0.02979566,
#   0.025009401,
#   0.022404056,
#   0.019100925,
#   0.015526035,
#   0.012482832,
#   0.010197569,
#   0.008720586,
#   0.0069661345,
#   0.0064210193,
#   0.005930588],
#  'consonant_recall': [0.8782514,
#   0.95466375,
#   0.96429664,
#   0.97039104,
#   0.9745403,
#   0.97748125,
#   0.9796455,
#   0.98186946,
#   0.9841731,
#   0.9860519,
#   0.9878311,
#   0.98901945,
#   0.9902675,
#   0.9913762,
#   0.9927372,
#   0.993879,
#   0.99452966,
#   0.9954259,
#   0.99612296,
#   0.99682003,
#   0.9973179,
#   0.99774945,
#   0.99805486,
#   0.9982274,
#   0.9983403],
#  'loss': [3.6690858738043945,
#   1.2487790287391745,
#   0.9723092698104383,
#   0.8260305842119946,
#   0.7184644643460929,
#   0.6331666114328234,
#   0.570250481449813,
#   0.5055765418609696,
#   0.44792689060868873,
#   0.39869042430544155,
#   0.350884455092232,
#   0.30223568196530315,
#   0.26543185591444446,
#   0.22667799906403643,
#   0.18492087320335152,
#   0.15149789760488364,
#   0.12571688840282094,
#   0.09894455308827288,
#   0.07627031823445472,
#   0.05916280970209854,
#   0.04645838500276601,
#   0.036889751548331975,
#   0.02957610140773418,
#   0.02600273679220849,
#   0.02464699904468203],
#  'lr': [0.001,
#   0.0009960613,
#   0.0009843073,
#   0.00096492335,
#   0.0009382152,
#   0.000904604,
#   0.00086461985,
#   0.00081889326,
#   0.0007681455,
#   0.00071317673,
#   0.000654854,
#   0.00059409696,
#   0.0005318639,
#   0.00046913614,
#   0.00040690304,
#   0.000346146,
#   0.00028782323,
#   0.00023285451,
#   0.00018210671,
#   0.00013638017,
#   9.639601e-05,
#   6.278481e-05,
#   3.6076646e-05,
#   1.6692711e-05,
#   4.9387068e-06],
#  'root_loss': [1.4272337,
#   0.45972508,
#   0.35665545,
#   0.30229697,
#   0.26315546,
#   0.23148732,
#   0.20726852,
#   0.18336402,
#   0.16213165,
#   0.14329208,
#   0.12554675,
#   0.10536084,
#   0.09184603,
#   0.0770271,
#   0.062021624,
#   0.04931703,
#   0.03959118,
#   0.029295819,
#   0.02178052,
#   0.016050512,
#   0.01223815,
#   0.008885616,
#   0.006961581,
#   0.00577642,
#   0.005341506],
#  'root_recall': [0.5599018,
#   0.8446989,
#   0.88514906,
#   0.90436834,
#   0.9178517,
#   0.9287791,
#   0.93665934,
#   0.9444998,
#   0.95115846,
#   0.9565757,
#   0.9621125,
#   0.968333,
#   0.9724756,
#   0.97653854,
#   0.9808272,
#   0.9843192,
#   0.9875191,
#   0.9906393,
#   0.9931089,
#   0.99501425,
#   0.99612296,
#   0.9970922,
#   0.9981279,
#   0.9983204,
#   0.9985129],
#  'val_consonant_loss': [0.20263898,
#   0.10510291,
#   0.12441008,
#   0.12166281,
#   0.08102105,
#   0.07970203,
#   0.08744965,
#   0.0700764,
#   0.078297555,
#   0.0767657,
#   0.061771605,
#   0.06662442,
#   0.07021316,
#   0.07144573,
#   0.067388654,
#   0.07351982,
#   0.08278326,
#   0.083883464,
#   0.08275514,
#   0.0911827,
#   0.086943224,
#   0.09081803,
#   0.08789879,
#   0.09381572,
#   0.08805774],
#  'val_consonant_recall': [0.9447122,
#   0.96851224,
#   0.96428996,
#   0.96865165,
#   0.9797451,
#   0.9790679,
#   0.97727543,
#   0.9814181,
#   0.9818562,
#   0.9825134,
#   0.9841267,
#   0.98456484,
#   0.9847441,
#   0.9855009,
#   0.9857399,
#   0.98532164,
#   0.9858395,
#   0.98605853,
#   0.9868552,
#   0.9865565,
#   0.986895,
#   0.98605853,
#   0.9869349,
#   0.98607844,
#   0.9867755],
#  'val_loss': [1.6275240336059007,
#   1.1090074664612155,
#   0.8825660975834796,
#   0.8930021728419772,
#   0.7629963813619759,
#   0.760612717187435,
#   0.7321581797290394,
#   0.6384315452806215,
#   0.6454832965256907,
#   0.7006248861323786,
#   0.5920789014860874,
#   0.5999183076559436,
#   0.5939783107290286,
#   0.6724587271402356,
#   0.6017617424973701,
#   0.6438586409120766,
#   0.7349558344760165,
#   0.7314800844165205,
#   0.7070362681650934,
#   0.7611919530446976,
#   0.7518606318525838,
#   0.7730317470681576,
#   0.7425297718428777,
#   0.783935504700069,
#   0.7576139995510721],
#  'val_root_loss': [0.5889807,
#   0.44167414,
#   0.32895464,
#   0.30585155,
#   0.29541165,
#   0.2866815,
#   0.27831158,
#   0.24281992,
#   0.24249744,
#   0.26530302,
#   0.22780101,
#   0.22858398,
#   0.22471672,
#   0.25218812,
#   0.22732045,
#   0.24706037,
#   0.2784897,
#   0.27758095,
#   0.26870987,
#   0.2881435,
#   0.28630376,
#   0.29571334,
#   0.2809556,
#   0.2983611,
#   0.2881166],
#  'val_root_recall': [0.82162917,
#   0.8669588,
#   0.9009759,
#   0.9082255,
#   0.9214101,
#   0.91927904,
#   0.92820156,
#   0.93596894,
#   0.93758214,
#   0.9384983,
#   0.94212306,
#   0.9460068,
#   0.94760007,
#   0.95020914,
#   0.95293766,
#   0.95120496,
#   0.9534356,
#   0.953336,
#   0.95706034,
#   0.9569209,
#   0.9577176,
#   0.9570205,
#   0.9589524,
#   0.9578769,
#   0.9585142],
#  'val_vowel_loss': [0.24692407,
#   0.120556064,
#   0.10024702,
#   0.15963647,
#   0.091152154,
#   0.10754761,
#   0.08808537,
#   0.08271542,
#   0.08219064,
#   0.093253255,
#   0.074705265,
#   0.076125726,
#   0.07433176,
#   0.096636765,
#   0.079732165,
#   0.07621799,
#   0.095193185,
#   0.09243495,
#   0.08686164,
#   0.09372241,
#   0.09231003,
#   0.09078689,
#   0.092719816,
#   0.09339733,
#   0.09332295],
#  'val_vowel_recall': [0.9348934,
#   0.9666401,
#   0.97641903,
#   0.96134233,
#   0.9790679,
#   0.97496516,
#   0.98084044,
#   0.98193586,
#   0.98273253,
#   0.98265284,
#   0.98358893,
#   0.98482376,
#   0.9857399,
#   0.98458475,
#   0.98548096,
#   0.9865764,
#   0.98482376,
#   0.98625773,
#   0.98721373,
#   0.9876519,
#   0.9875324,
#   0.9875921,
#   0.98751247,
#   0.9874925,
#   0.9878311],
#  'vowel_loss': [0.44487658,
#   0.17292726,
#   0.13335712,
#   0.11403273,
#   0.09842188,
#   0.08752816,
#   0.07993803,
#   0.07037474,
#   0.06336552,
#   0.0579901,
#   0.051598266,
#   0.047244646,
#   0.04223218,
#   0.037960965,
#   0.031066908,
#   0.027897704,
#   0.024171991,
#   0.021239458,
#   0.017173523,
#   0.014583552,
#   0.011780439,
#   0.010400892,
#   0.008684059,
#   0.008025416,
#   0.008034653],
#  'vowel_recall': [0.8391954,
#   0.9498041,
#   0.9630552,
#   0.96948814,
#   0.9742349,
#   0.97764057,
#   0.9805152,
#   0.9826927,
#   0.9846976,
#   0.98602533,
#   0.9876519,
#   0.98866093,
#   0.99006176,
#   0.9913098,
#   0.99259114,
#   0.99343425,
#   0.9944367,
#   0.99496114,
#   0.99589723,
#   0.9965412,
#   0.9971453,
#   0.9973113,
#   0.99775606,
#   0.9978955,
#   0.99792206],
#  'weighted_recall': [0.7093125730752945,
#   0.8984664231538773,
#   0.9244124889373779,
#   0.9371539652347565,
#   0.946119636297226,
#   0.9531700164079666,
#   0.9583698362112045,
#   0.963390439748764,
#   0.9677969068288803,
#   0.9713071584701538,
#   0.9749269932508469,
#   0.9785865992307663,
#   0.9813201129436493,
#   0.9839407801628113,
#   0.986745685338974,
#   0.988987922668457,
#   0.9910011291503906,
#   0.9929164201021194,
#   0.9945595115423203,
#   0.9958474338054657,
#   0.9966772794723511,
#   0.9973112791776657,
#   0.9980166703462601,
#   0.9981909245252609,
#   0.9983220547437668]}

# %%
history.history['val_root_recall']
# Out:
# [0.82162917,
#  0.8669588,
#  0.9009759,
#  0.9082255,
#  0.9214101,
#  0.91927904,
#  0.92820156,
#  0.93596894,
#  0.93758214,
#  0.9384983,
#  0.94212306,
#  0.9460068,
#  0.94760007,
#  0.95020914,
#  0.95293766,
#  0.95120496,
#  0.9534356,
#  0.953336,
#  0.95706034,
#  0.9569209,
#  0.9577176,
#  0.9570205,
#  0.9589524,
#  0.9578769,
#  0.9585142]

# %%
history.history['val_weighted_recall']= 0.5*np.array(history.history['val_root_recall'])+0.25*np.array(history.history['val_consonant_recall'])+0.25*np.array(history.history['val_vowel_recall'])

# %%
history.history['val_weighted_recall']
# Out:
# array([0.88071597, 0.91726744, 0.9356652 , 0.93661124, 0.95040834,
#        0.9481478 , 0.95362973, 0.95882297, 0.9599382 , 0.9605407 ,
#        0.96299046, 0.9653505 , 0.96642107, 0.967626  , 0.96927404,
#        0.96857697, 0.9693836 , 0.96974707, 0.97204745, 0.9720125 ,
#        0.97246563, 0.9719229 , 0.973088  , 0.9723312 , 0.97290874],
#       dtype=float32)

# %%
from matplotlib import pyplot as plt

# %%
# %matplotlib inline

plt.style.use('ggplot')
plt.figure()
plt.plot(np.arange(0, epochs), history.history['loss'], label='loss')
plt.plot(np.arange(0, epochs), history.history['val_loss'], label='val_loss')
plt.plot(np.arange(0, epochs), history.history['val_root_loss'], label='val_root_loss')
plt.plot(np.arange(0, epochs), history.history['val_vowel_loss'], label='val_vowel_loss')
plt.plot(np.arange(0, epochs), history.history['val_consonant_loss'], label='val_consonant_loss')

    
plt.title('loss')
plt.xlabel('Epoch #')
plt.ylabel('Loss')
plt.legend(loc='upper right')
plt.show()

# %%
plt.style.use('ggplot')
plt.figure()
plt.plot(np.arange(0, epochs), history.history['weighted_recall'], label='weighted_recall')
plt.plot(np.arange(0, epochs), history.history['val_root_recall'], label='val_root_recall')
plt.plot(np.arange(0, epochs), history.history['val_vowel_recall'], label='val_vowel_recall')
plt.plot(np.arange(0, epochs), history.history['val_consonant_recall'], label='val_consonant_recall')

    
plt.title('recall')
plt.xlabel('Epoch #')
plt.ylabel('Loss')
plt.legend(loc='upper right')
plt.show()

# %%
plt.style.use('ggplot')
plt.figure()
plt.plot(np.arange(0, epochs), history.history['lr'], label='lr')

    
plt.title('lr')
plt.xlabel('Epoch #')
plt.ylabel('Loss')
plt.legend(loc='upper right')
plt.show()

# %%
plt.style.use('ggplot')
plt.figure()
plt.plot(np.arange(0, epochs), history.history['weighted_recall'], label='w_recall')
plt.plot(np.arange(0, epochs), history.history['val_weighted_recall'], label='val_w_recall')
    
plt.title('recall')
plt.xlabel('Epoch #')
plt.ylabel('Loss')
plt.legend(loc='upper right')
plt.show()
