# %%
#config consts

INPUT_DIR ='/content/drive/My Drive/kaggle/melanoma/input/'
SUBS_DIR='subs/'
OUTPUT_DIR = '/content/drive/My Drive/kaggle/melanoma/output/'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import math
from scipy.stats import rankdata

# %%
#https://www.kaggle.com/shonenkov/inference-single-model-melanoma-starter v3
sub1 = pd.read_csv(INPUT_DIR+SUBS_DIR+'submission_shon0927.csv')

#my own solution 0918
#effnet b5; aug:random_flip_left_right; no metadata; no pl; 70k imgs 512x512; 
#train rate = 0.95; epochs=5; bs=64;lr: 0.001; 0.001; 0.0001; 0.0001; 0.0001; CV = 0.9303 AUC
sub2 = pd.read_csv(INPUT_DIR+SUBS_DIR+'submission_efficientnetb5_v3.csv')

#my own
sub3 = pd.read_csv(INPUT_DIR+SUBS_DIR+'submission_efficientnetb7.csv')

#https://www.kaggle.com/khoongweihao/siim-isic-multiple-model-training-stacking v6
sub4 = pd.read_csv(INPUT_DIR+SUBS_DIR+'submission_blend0934.csv')

#https://www.kaggle.com/nroman/melanoma-pytorch-starter-efficientnet v13
sub5 = pd.read_csv(INPUT_DIR+SUBS_DIR+'submission_roman918.csv')

#https://www.kaggle.com/shonenkov/inference-melanoma-crazy-fast v4
sub6 = pd.read_csv(INPUT_DIR+SUBS_DIR+'submission_shon_serenext50_928.csv')

#https://www.kaggle.com/ajaykumar7778/melanoma-tpu-efficientnet-b5-dense-head?scriptVersionId=34982173 v1
sub7 = pd.read_csv(INPUT_DIR+SUBS_DIR+'submission_7778_910.csv')

#https://www.kaggle.com/ragnar123/catboost-metadata v1
sub8 = pd.read_csv(INPUT_DIR+SUBS_DIR+'submission_xg_cnn_94.csv')

#https://www.kaggle.com/agentauers/incredible-tpus-finetune-effnetb0-b6-at-once V5
sub9 = pd.read_csv(INPUT_DIR+SUBS_DIR+'submission_models_blended_936.csv')

#https://www.kaggle.com/nroman/melanoma-pytorch-starter-efficientnet?scriptVersionId=36430890 v19
sub10 =  pd.read_csv(INPUT_DIR+SUBS_DIR+'submission_roman_925.csv')

#https://www.kaggle.com/ragnar123/rank-then-blend/ v2
sub11 = pd.read_csv(INPUT_DIR+SUBS_DIR+'blend_sub_946.csv')

#https://www.kaggle.com/apthagowda/melanoma-efficientnet-b6-tpu-tta v2
sub12 = pd.read_csv(INPUT_DIR+SUBS_DIR+ 'submission_b6_927.csv')

#https://www.kaggle.com/hmendonca/melanoma-neat-pytorch-lightning-native-amp v8
sub13 = pd.read_csv(INPUT_DIR+SUBS_DIR+ 'submission_929.csv')

#https://www.kaggle.com/vbhargav875/efficientnet-b5-b6-b7-tf-keras 939 v5
sub14 = pd.read_csv(INPUT_DIR+SUBS_DIR+ 'submission_EfficientNet_B7_Blend_6.csv')

#https://www.kaggle.com/paklau9/minmax-highest-public-lb-9619 v16
sub15 = pd.read_csv(INPUT_DIR+SUBS_DIR+ 'submission_9619.csv')

#https://www.kaggle.com/khoongweihao/post-processing-technique-c-f-1st-place-jigsaw v6
sub16 = pd.read_csv(INPUT_DIR+SUBS_DIR+ 'submission_9581.csv')

#https://www.kaggle.com/datafan07/analysis-of-melanoma-metadata-and-effnet-ensemble v28
sub17 = pd.read_csv(INPUT_DIR+SUBS_DIR+ 'ensembled_9513.csv')

#https://www.kaggle.com/rajnishe/rc-fork-siim-isic-melanoma-384x384 v17
sub18 = pd.read_csv(INPUT_DIR+SUBS_DIR+ 'sub_EfficientNetB2_384.csv')



r_target1 = rankdata(np.array(sub1['target']))
r_target2 = rankdata(np.array(sub2['target']))
r_target3 = rankdata(np.array(sub4['target']))
r_target4 = rankdata(np.array(sub5['target']))
r_target5 = rankdata(np.array(sub6['target']))
r_target6 = rankdata(np.array(sub7['target']))
r_target7 = rankdata(np.array(sub8['target']))
r_target8 = rankdata(np.array(sub9['target']))
r_target9 = rankdata(np.array(sub10['target']))
r_target10 = rankdata(np.array(sub11['target']))
r_target11 = rankdata(np.array(sub12['target']))
r_target12 = rankdata(np.array(sub13['target']))
r_target13 = rankdata(np.array(sub14['target']))
r_target14 = rankdata(np.array(sub15['target']))
r_target15 = rankdata(np.array(sub16['target']))
r_target16 = rankdata(np.array(sub17['target']))
r_target17 = rankdata(np.array(sub18['target']))

# %%
    sub_es = sub1[['image_name']]
    sub_es['target']  = (r_target1+r_target2+r_target3+r_target4+r_target5+r_target6+r_target7+r_target8+r_target9+
                         r_target10+r_target11+r_target12+r_target13+r_target14+r_target15+r_target16+r_target17)/17.0

    sub_es.to_csv(OUTPUT_DIR+'submission_blendranked_v43.csv', index=False)
    sub_es.head()
# Out:
#      image_name       target
# 0  ISIC_0052060  3413.147059
# 1  ISIC_0052349  2117.264706
# 2  ISIC_0058510  2694.823529
# 3  ISIC_0073313  1567.676471
# 4  ISIC_0073502  5742.000000

# %%
#https://www.kaggle.com/agentauers/incredible-tpus-finetune-effnetb0-b6-at-once v5
SUBS_DIR='itpu/'
sub0 = pd.read_csv(INPUT_DIR+SUBS_DIR+'submission_model_0.csv')
sub1 = pd.read_csv(INPUT_DIR+SUBS_DIR+'submission_model_1.csv')
sub2 = pd.read_csv(INPUT_DIR+SUBS_DIR+'submission_model_2.csv')
sub3 = pd.read_csv(INPUT_DIR+SUBS_DIR+'submission_model_3.csv')
sub4 = pd.read_csv(INPUT_DIR+SUBS_DIR+'submission_model_4.csv')
sub5 = pd.read_csv(INPUT_DIR+SUBS_DIR+'submission_model_5.csv')
sub6 = pd.read_csv(INPUT_DIR+SUBS_DIR+'submission_model_6.csv')

r_target0 = rankdata(np.array(sub0['target']))
r_target1 = rankdata(np.array(sub1['target']))
r_target2 = rankdata(np.array(sub2['target']))
r_target3 = rankdata(np.array(sub3['target']))
r_target4 = rankdata(np.array(sub4['target']))
r_target5 = rankdata(np.array(sub5['target']))
r_target6 = rankdata(np.array(sub6['target']))


sub_es = sub1[['image_name']]
sub_es['target'] = (r_target0+r_target3+r_target4)/3.0
sub_es.to_csv(OUTPUT_DIR+'submission_blendranked_itpu_v21.csv', index=False)
sub_es.head()
# Out:
#      image_name       target
# 0  ISIC_0052060  6614.333333
# 1  ISIC_0052349  3947.333333
# 2  ISIC_0058510  3195.333333
# 3  ISIC_0073313  1804.666667
# 4  ISIC_0073502  4529.000000
